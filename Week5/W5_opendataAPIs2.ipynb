# %% [markdown]
# # Learning goals
# After today's lesson you should be able to:
# - Use the Google Maps API via the `googlemaps` library to:
#     - Find geometry routes between two points
#     - Geocode addresses
#     - Get points of interest

# %%
import pandas as pd
import numpy as np
import geopandas as gpd


import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context(context='paper')

# os.getcwd()

# %% [markdown]
# # 1. Google Cloud
#
# Google Cloud is a set of "cloud computing" services that consists of physical assets like computers and hard drives, and virtual resources, like computing environments, that is often used for data storage and management, tools for computing and software development, machine learning, and more.
#
# You may have heard of Amazon AWS and Microsoft Azure, these are Amazon and Microsoft's cloud computing offerings that all have similar capabilities.
#
# To note: These "cloud" computers and services don't live in some ephemeral space. You can actually see the locations of [Google Data Centers](https://www.google.com/about/datacenters/locations/).
#
# This is what the Dalles, Oregon Google data center looks like from satellite imagery. It's just a giant building filled with a lot of computers:
# <iframe src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1390.42297102674!2d-121.20177632936587!3d45.63191557459542!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x54961ebdb45cdec5%3A0x4bde13efb5371001!2sThe%20Dalles%20Google%20Data%20Center!5e1!3m2!1sen!2sus!4v1676841727765!5m2!1sen!2sus" width="1000" height="600"  style="display: block; margin: 0 auto"  allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>
#
# The Google Maps API is a tool that allows us to use some of the engines and retrieve datasets underlying Google Maps.
#
#
# ## 1.1 Getting started
# To get started, we need to **create an API key**. An API key is a code or id provided by the client that is passed to the API that allows it to identify which user/project is calling the API to keep track of your usage and access. It also allows you to keep track of your API usage for particular projects and applications.
#
# You'll need your Cornell account to proceed. Please refer my Slack message from earlier this week on the details.
#
# - Go to the [Google Cloud console](https://console.cloud.google.com/), which is your landing page for all Google computing services (geocoding API is one of many tools you can use through the Google Cloud).
# - If your default account is your personal gmail (like it is mine), make sure to switch it to your Cornell email on the top right-hand corner.
# - You'll have to agree to their terms of service before proceeding (I think). An [interesting read](https://cloud.google.com/terms/?authuser=1) for another time.
# - This should take you to a page like this:
# </figure>
# <img src="https://www.dropbox.com/s/wj9igmb9dhlb3ba/Screen%20Shot%202023-02-19%20at%204.29.43%20PM.png?dl=1" alt="drawing" width="1000" style="display: block; margin: 0 auto"/>
# </figure>
#
# - In the upper-left corner, click **Select a project** and **NEW PROJECT**. All API keys are associated with projects, which is more for developers who are using the services more heavily. This is so that we separate usage and keep track of what projects are using how much of which resources.
# </figure>
# <img src="https://www.dropbox.com/s/vwje4uz06tlvlo9/Screen%20Shot%202023-02-19%20at%204.33.29%20PM.png?dl=1" alt="drawing" width="1000" style="display: block; margin: 0 auto"/>
# </figure>
#
# - Here, input a project name. You'll need to create a **globally unique** name, all lower case, no spaces only dashes name. I'm calling this project `introUDS-wx233`. You can call yours `introUDS-YOURNETID`
# - Once you click ok it will take a few seconds to create the project.
# - In the console, select your new project `introUDS-wx233` (for me).
# - From here, go to the sidebar menu, select **Google Maps Platform->APIs**
#
# </figure>
# <img src="https://www.dropbox.com/s/ru6b367zd6jwh1l/Screen%20Shot%202023-02-19%20at%204.34.48%20PM.png?dl=1" alt="drawing" width="1000" style="display: block; margin: 0 auto"/>
# </figure>
#
# - You will be given an API key. Save that down somewhere.
# - You will also be asked to **Protect your API key** by limiting its use.
#     - Select **API restriction** and check all the APIs in the dropdown for now.
#
# </figure>
# <img src="https://www.dropbox.com/s/ked2jfofqpqqpab/Screen%20Shot%202023-02-19%20at%204.37.33%20PM.png?dl=1" alt="drawing" width="1000" style="display: block; margin: 0 auto"/>
# </figure>

# %%
# api_key ='AIzaSyCJU8f3hHy9F7P4NHjQctjn3cK0UTUu0gc' #Wenfei's

# %% [markdown]
# ## 1.2 Installing the `googlemaps` library
# Here, the `-U` flag stands for installing the latest version of the library.

# %%
# !pip install -U googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.11.17)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40746 sha256=df3603fb4d27be40bf4e6819c07d2f240011c58f924f6b4cf8a8ecf3972c106e
#   Stored in directory: c:\users\desai\appdata\local\pip\cache\wheels\d9\5f\46\54a2bdb4bcb07d3faba4463d2884865705914cc72a7b8bb5f0
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %% [markdown]
# ## 1.3 Geocoding
# [Google Geocoding API documentation](https://developers.google.com/maps/documentation/geocoding/overview)

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key=api_key)

# %%
# Geocoding an address
geocode_result = gmaps.geocode("921 University Ave, Ithaca, NY 14853")

# %%
geocode_result
# Out:
# [{'address_components': [{'long_name': '921',
#     'short_name': '921',
#     'types': ['street_number']},
#    {'long_name': 'University Avenue',
#     'short_name': 'University Ave',
#     'types': ['route']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '14853', 'short_name': '14853', 'types': ['postal_code']}],
#   'formatted_address': '921 University Ave, Ithaca, NY 14853, USA',
#   'geometry': {'location': {'lat': 42.4512236, 'lng': -76.4828622},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 42.45266253029149,
#      'lng': -76.48148931970849},
#     'southwest': {'lat': 42.4499645697085, 'lng': -76.4841872802915}}},
#   'place_id': 'ChIJN8x-8SCC0IkRNp757KZUFG8',
#   'plus_code': {'compound_code': 'FG28+FV Ithaca, NY',
#    'global_code': '87J5FG28+FV'},
#   'types': ['street_address']}]

# %% [markdown]
# We were returned a JSON, which is just a nested dictionary of key-value pairs.
#
# In its simplest version, this is how JSONs and dictionaries are structured:
#
# </figure>
# <img src="https://www.softwaretestinghelp.com/wp-content/qa/uploads/2017/12/Including-Car-in-Employee-JSON.jpg" alt="drawing" width="600" style="display: block; margin: 0 auto"/>
# </figure>
#
# What "nested" means is just that a the value associated with a key can be a dictionary itself.
# </figure>
# <img src="https://help.rapid7.com/insightidr/content/resources/images/json/nested-json.png" alt="drawing" width="600" style="display: block; margin: 0 auto"/>
# </figure>
#
#
#
# Let's dig into the part of the JSON that we actually care about, which is that `'geometry': {'location': {'lat': 42.4512236, 'lng': -76.4828622},` section.

# %%
### That was a  list, so let's get the first value
geocode_result[0]
# Out:
# {'address_components': [{'long_name': '921',
#    'short_name': '921',
#    'types': ['street_number']},
#   {'long_name': 'University Avenue',
#    'short_name': 'University Ave',
#    'types': ['route']},
#   {'long_name': 'Ithaca',
#    'short_name': 'Ithaca',
#    'types': ['locality', 'political']},
#   {'long_name': 'Tompkins County',
#    'short_name': 'Tompkins County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'New York',
#    'short_name': 'NY',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']},
#   {'long_name': '14853', 'short_name': '14853', 'types': ['postal_code']}],
#  'formatted_address': '921 University Ave, Ithaca, NY 14853, USA',
#  'geometry': {'location': {'lat': 42.4512236, 'lng': -76.4828622},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 42.45266253029149,
#     'lng': -76.48148931970849},
#    'southwest': {'lat': 42.4499645697085, 'lng': -76.4841872802915}}},
#  'place_id': 'ChIJN8x-8SCC0IkRNp757KZUFG8',
#  'plus_code': {'compound_code': 'FG28+FV Ithaca, NY',
#   'global_code': '87J5FG28+FV'},
#  'types': ['street_address']}

# %%
geocode_result[0]['geometry']['location']
# Out:
# {'lat': 42.4512236, 'lng': -76.4828622}

# %%
print(geocode_result[0]['geometry']['location']['lng'],
     geocode_result[0]['geometry']['location']['lat'])
# Out:
# -76.4828622 42.4512236

# %% [markdown]
# Now that we have the lng/lat, you can see how we can turn these into geometries.

# %% [markdown]
# ## 1.2.1 Geocoding a df
# Let's use an example that has multiple rows. The geocoder only processes 1 request at a time, so we have to run the geocoder on each row of a df.
#
# Let's take a look at the Department of Building's Permit Issuance dataset. The DOB requires a permit for construction and demolition activities.

# %%
dob_permits_url = 'https://data.cityofnewyork.us/resource/ipu4-2q9a.json?$limit=5'
dob_permits= pd.read_json(dob_permits_url)

# %%
dob_permits
# Out:
#          borough    bin__  house__       street_name      job__  job_doc___  \
# 0      MANHATTAN  1088749        1       MADISON AVE  141008987           1
# 1  STATEN ISLAND  5076937       87     BOYLAN STREET  540218539           1
# 2  STATEN ISLAND  5001506      217  LAFAYETTE AVENUE  540218575           1
# 3  STATEN ISLAND  5067021      170    OAKDALE STREET  540218600           1
# 4  STATEN ISLAND  5058036      273         10 STREET  540218628           1
#
#   job_type self_cert  block  lot  ...           dobrundate  permit_si_no  \
# 0       A3         Y    853    2  ...  05/11/2022 00:00:00       3905851
# 1       A2         Y   5687   66  ...  05/11/2022 00:00:00       3905852
# 2       A2         Y     64   22  ...  05/11/2022 00:00:00       3905853
# 3       A2         Y   5260    1  ...  05/11/2022 00:00:00       3905854
# 4       A2         Y   4242   45  ...  05/11/2022 00:00:00       3905855
#
#    gis_latitude gis_longitude gis_council_district gis_census_tract  \
# 0     40.740909    -73.987947                    2               56
# 1     40.563654    -74.179584                   51            17008
# 2     40.639633    -74.094169                   49               81
# 3     40.544597    -74.157153                   51            15601
# 4     40.566798    -74.119726                   50              134
#
#                                  gis_nta_name  residential special_district_1  \
# 0  Hudson Yards-Chelsea-Flatiron-Union Square          NaN                NaN
# 1                               Arden Heights          YES                SRD
# 2   West New Brighton-New Brighton-St. George          YES                 HS
# 3                                 Great Kills          YES                SRD
# 4                      New Dorp-Midland Beach          YES                NaN
#
#         site_fill
# 0             NaN
# 1  NOT APPLICABLE
# 2  NOT APPLICABLE
# 3  NOT APPLICABLE
# 4  NOT APPLICABLE
#
# [5 rows x 45 columns]

# %% [markdown]
# See that we have different columns that refer to the
# - House number
# - Street Name
# - (Optionally: Borough)
#
# We know all the address are in NYC. All of our relevant columns need to be strings in order for us to concatenate these columns together.

# %%
dob_permits.dtypes
# Out:
# borough                       object
# bin__                          int64
# house__                        int64
# street_name                   object
# job__                          int64
# job_doc___                     int64
# job_type                      object
# self_cert                     object
# block                          int64
# lot                            int64
# community_board                int64
# zip_code                       int64
# bldg_type                      int64
# work_type                     object
# permit_status                 object
# filing_status                 object
# permit_type                   object
# permit_sequence__              int64
# permit_subtype                object
# filing_date                   object
# issuance_date                 object
# expiration_date               object
# job_start_date                object
# permittee_s_first_name        object
# permittee_s_last_name         object
# permittee_s_business_name     object
# permittee_s_phone__            int64
# permittee_s_license_type      object
# permittee_s_license__          int64
# owner_s_business_type         object
# non_profit                    object
# owner_s_business_name         object
# owner_s_first_name            object
# owner_s_last_name             object
# owner_s_phone__                int64
# dobrundate                    object
# permit_si_no                   int64
# gis_latitude                 float64
# gis_longitude                float64
# gis_council_district           int64
# gis_census_tract               int64
# gis_nta_name                  object
# residential                   object
# special_district_1            object
# site_fill                     object
# dtype: object

# %%
dob_permits['house__'] = dob_permits['house__'].astype(str)
dob_permits['street_name'] = dob_permits['street_name'].astype(str)
dob_permits['borough'] = dob_permits['borough'].astype(str)

# %%
dob_permits['address'] = dob_permits['house__'] + ' ' + \
                        dob_permits['street_name'] + ', ' + \
                        dob_permits['borough'] + ', ' + 'NY'

# %%
dob_permits['address']
# Out:
# 0               1 MADISON AVE, MANHATTAN, NY
# 1        87 BOYLAN STREET, STATEN ISLAND, NY
# 2    217 LAFAYETTE AVENUE, STATEN ISLAND, NY
# 3      170 OAKDALE STREET, STATEN ISLAND, NY
# 4           273 10 STREET, STATEN ISLAND, NY
# Name: address, dtype: object

# %% [markdown]
# Let's first create two new columns: `lng` and `lat`

# %%
dob_permits['lng'] = ""
dob_permits['lat'] = ""

# %%
for i, row in dob_permits.iterrows(): 
    print(f"Current row is {i}")
    row_result = gmaps.geocode(row['address'])

    ## We are going to assign the geocoded lat/lng to each row
    dob_permits.loc[i,'lat'] = row_result[0]['geometry']['location']['lat']
    dob_permits.loc[i,'lng'] = row_result[0]['geometry']['location']['lng']
# Out:
# Current row is 0
# Current row is 1
# Current row is 2
# Current row is 3
# Current row is 4

# %%
dob_permits
# Out:
#          borough    bin__ house__       street_name      job__  job_doc___  \
# 0      MANHATTAN  1088749       1       MADISON AVE  141008987           1
# 1  STATEN ISLAND  5076937      87     BOYLAN STREET  540218539           1
# 2  STATEN ISLAND  5001506     217  LAFAYETTE AVENUE  540218575           1
# 3  STATEN ISLAND  5067021     170    OAKDALE STREET  540218600           1
# 4  STATEN ISLAND  5058036     273         10 STREET  540218628           1
#
#   job_type self_cert  block  lot  ...  gis_longitude  gis_council_district  \
# 0       A3         Y    853    2  ...     -73.987947                     2
# 1       A2         Y   5687   66  ...     -74.179584                    51
# 2       A2         Y     64   22  ...     -74.094169                    49
# 3       A2         Y   5260    1  ...     -74.157153                    51
# 4       A2         Y   4242   45  ...     -74.119726                    50
#
#    gis_census_tract                                gis_nta_name residential  \
# 0                56  Hudson Yards-Chelsea-Flatiron-Union Square         NaN
# 1             17008                               Arden Heights         YES
# 2                81   West New Brighton-New Brighton-St. George         YES
# 3             15601                                 Great Kills         YES
# 4               134                      New Dorp-Midland Beach         YES
#
#   special_district_1       site_fill                                  address  \
# 0                NaN             NaN             1 MADISON AVE, MANHATTAN, NY
# 1                SRD  NOT APPLICABLE      87 BOYLAN STREET, STATEN ISLAND, NY
# 2                 HS  NOT APPLICABLE  217 LAFAYETTE AVENUE, STATEN ISLAND, NY
# 3                SRD  NOT APPLICABLE    170 OAKDALE STREET, STATEN ISLAND, NY
# 4                NaN  NOT APPLICABLE         273 10 STREET, STATEN ISLAND, NY
#
#          lng        lat
# 0 -73.987518  40.741149
# 1 -74.179754  40.563833
# 2 -74.093874  40.639461
# 3 -74.157021  40.544417
# 4 -74.119936  40.566948
#
# [5 rows x 48 columns]

# %%
## 
dob_permits_geo = gpd.GeoDataFrame(dob_permits,
                            geometry=gpd.points_from_xy(dob_permits['lng'], dob_permits['lat']),
                            crs='EPSG:4326')

# %%
dob_permits_geo.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_811f4f1ea825201311b1a94c5e6a6e92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_811f4f1ea825201311b1a94c5e6a6e92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_811f4f1ea825201311b1a94c5e6a6e92 = L.map(
#                 &quot;map_811f4f1ea825201311b1a94c5e6a6e92&quot;,
#                 {
#                     center: [40.64278315, -74.0836358],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_811f4f1ea825201311b1a94c5e6a6e92);
#
#
#
#
#
#             var tile_layer_b5f6322797065d3ef767d75ae687c98f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5f6322797065d3ef767d75ae687c98f.addTo(map_811f4f1ea825201311b1a94c5e6a6e92);
#
#
#             map_811f4f1ea825201311b1a94c5e6a6e92.fitBounds(
#                 [[40.5444169, -74.1797536], [40.7411494, -73.987518]],
#                 {}
#             );
#
#
#         function geo_json_1a308ad40e79b64971182a03fb2bb2d4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1a308ad40e79b64971182a03fb2bb2d4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1a308ad40e79b64971182a03fb2bb2d4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1a308ad40e79b64971182a03fb2bb2d4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1a308ad40e79b64971182a03fb2bb2d4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_1a308ad40e79b64971182a03fb2bb2d4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1a308ad40e79b64971182a03fb2bb2d4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1a308ad40e79b64971182a03fb2bb2d4 = L.geoJson(null, {
#                 onEachFeature: geo_json_1a308ad40e79b64971182a03fb2bb2d4_onEachFeature,
#
#                 style: geo_json_1a308ad40e79b64971182a03fb2bb2d4_styler,
#                 pointToLayer: geo_json_1a308ad40e79b64971182a03fb2bb2d4_pointToLayer,
#         });
#
#         function geo_json_1a308ad40e79b64971182a03fb2bb2d4_add (data) {
#             geo_json_1a308ad40e79b64971182a03fb2bb2d4
#                 .addData(data);
#         }
#             geo_json_1a308ad40e79b64971182a03fb2bb2d4_add({&quot;bbox&quot;: [-74.1797536, 40.5444169, -73.987518, 40.7411494], &quot;features&quot;: [{&quot;bbox&quot;: [-73.987518, 40.7411494, -73.987518, 40.7411494], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.987518, 40.7411494], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;address&quot;: &quot;1 MADISON AVE, MANHATTAN, NY&quot;, &quot;bin__&quot;: 1088749, &quot;bldg_type&quot;: 2, &quot;block&quot;: 853, &quot;borough&quot;: &quot;MANHATTAN&quot;, &quot;community_board&quot;: 105, &quot;dobrundate&quot;: &quot;05/11/2022 00:00:00&quot;, &quot;expiration_date&quot;: &quot;05/10/2023&quot;, &quot;filing_date&quot;: &quot;05/10/2022&quot;, &quot;filing_status&quot;: &quot;INITIAL&quot;, &quot;gis_census_tract&quot;: 56, &quot;gis_council_di

# %% [markdown]
# ## Q.1 Geocoding
# - Create a DF of any five places you have visited or traveled to across the world
#     - Try inserting some typos, alternative spellings or names for these places. (For ex, Sibley Hall instead of 921 University Ave.)
# - Geocode these using the google maps API.
# - Map these five points, using contextily as a basemap service.
# - How accurate was the geocoder in finding the locations of these places?

# %%
## INSERT YOUR CODE HERE
myVisits = pd.DataFrame(["Queen's Museum, New York", 
                         "Campo di Fiori, Rome, Italy", 
                         "Rijkesmuseum, Amsterdam, Netherlands",
                         "Centre Pompidou, Paris, France",
                         "Laomatou Hotpot, Bellevue, Washington"], columns=["location"])

# %%
myVisits['lng'] = ""
myVisits['lat'] = ""  

for i, row in myVisits.iterrows(): 
    print(f"Current row is {i}")
    row_result = gmaps.geocode(row['location'])

    ## We are going to assign the geocoded lat/lng to each row
    myVisits.loc[i,'lat'] = row_result[0]['geometry']['location']['lat']
    myVisits.loc[i,'lng'] = row_result[0]['geometry']['location']['lng']
# Out:
# Current row is 0
# Current row is 1
# Current row is 2
# Current row is 3
# Current row is 4

# %%
myVisits_geo = gpd.GeoDataFrame(myVisits,
                            geometry=gpd.points_from_xy(myVisits['lng'], myVisits['lat']),
                            crs='EPSG:4326')

myVisits_geo.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d73723a0dd5a552ef13b8cac55b3d9bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d73723a0dd5a552ef13b8cac55b3d9bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d73723a0dd5a552ef13b8cac55b3d9bf = L.map(
#                 &quot;map_d73723a0dd5a552ef13b8cac55b3d9bf&quot;,
#                 {
#                     center: [46.5529558, -54.86310085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d73723a0dd5a552ef13b8cac55b3d9bf);
#
#
#
#
#
#             var tile_layer_48beed0f44a92c9861078a431cdb0a56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_48beed0f44a92c9861078a431cdb0a56.addTo(map_d73723a0dd5a552ef13b8cac55b3d9bf);
#
#
#             map_d73723a0dd5a552ef13b8cac55b3d9bf.fitBounds(
#                 [[40.745914, -122.1984037], [52.3599976, 12.472202]],
#                 {}
#             );
#
#
#         function geo_json_0be66d0201794251e793b8af98a0f8f9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0be66d0201794251e793b8af98a0f8f9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0be66d0201794251e793b8af98a0f8f9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0be66d0201794251e793b8af98a0f8f9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0be66d0201794251e793b8af98a0f8f9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0be66d0201794251e793b8af98a0f8f9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0be66d0201794251e793b8af98a0f8f9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0be66d0201794251e793b8af98a0f8f9 = L.geoJson(null, {
#                 onEachFeature: geo_json_0be66d0201794251e793b8af98a0f8f9_onEachFeature,
#
#                 style: geo_json_0be66d0201794251e793b8af98a0f8f9_styler,
#                 pointToLayer: geo_json_0be66d0201794251e793b8af98a0f8f9_pointToLayer,
#         });
#
#         function geo_json_0be66d0201794251e793b8af98a0f8f9_add (data) {
#             geo_json_0be66d0201794251e793b8af98a0f8f9
#                 .addData(data);
#         }
#             geo_json_0be66d0201794251e793b8af98a0f8f9_add({&quot;bbox&quot;: [-122.1984037, 40.745914, 12.472202, 52.3599976], &quot;features&quot;: [{&quot;bbox&quot;: [-73.8467247, 40.745914, -73.8467247, 40.745914], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.8467247, 40.745914], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;lat&quot;: 40.745914, &quot;lng&quot;: -73.8467247, &quot;location&quot;: &quot;Queen\u0027s Museum, New York&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [12.472202, 41.8954097, 12.472202, 41.8954097], &quot;geometry&quot;: {&quot;coordinates&quot;: [12.472202, 41.8954097], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;lat&quot;: 41.8954097, &quot;lng&quot;: 12.472202, &quot;location&quot;: &quot

# %% [markdown]
# ## 1.2.2 Reverse geocoding
# In the same way that you can turn addresses to Lng/Lats, you can do the same.

# %%
## Note, that the format here is Lat, Lng!
reverse_geocode_result = gmaps.reverse_geocode((42.4512236,-76.4828622))

# %%
reverse_geocode_result
# Out:
# [{'address_components': [{'long_name': '921',
#     'short_name': '921',
#     'types': ['street_number']},
#    {'long_name': 'University Avenue',
#     'short_name': 'University Ave',
#     'types': ['route']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '14850', 'short_name': '14850', 'types': ['postal_code']}],
#   'formatted_address': '921 University Ave, Ithaca, NY 14850, USA',
#   'geometry': {'location': {'lat': 42.4512236, 'lng': -76.4828622},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 42.4525725802915,
#      'lng': -76.4815132197085},
#     'southwest': {'lat': 42.4498746197085, 'lng': -76.48421118029151}}},
#   'place_id': 'ChIJ1wY8fG6D0IkRYbPFAkctpjA',
#   'plus_code': {'compound_code': 'FG28+FV Ithaca, NY, USA',
#    'global_code': '87J5FG28+FV'},
#   'types': ['establishment', 'point_of_interest']},
#  {'address_components': [{'long_name': '921',
#     'short_name': '921',
#     'types': ['street_number']},
#    {'long_name': 'University Avenue',
#     'short_name': 'University Ave',
#     'types': ['route']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '14853', 'short_name': '14853', 'types': ['postal_code']}],
#   'formatted_address': '921 University Ave, Ithaca, NY 14853, USA',
#   'geometry': {'location': {'lat': 42.4512236, 'lng': -76.4828622},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 42.4525725802915,
#      'lng': -76.4815132197085},
#     'southwest': {'lat': 42.4498746197085, 'lng': -76.48421118029151}}},
#   'place_id': 'ChIJN8x-8SCC0IkRNp757KZUFG8',
#   'plus_code': {'compound_code': 'FG28+FV Ithaca, NY, USA',
#    'global_code': '87J5FG28+FV'},
#   'types': ['street_address']},
#  {'address_components': [{'long_name': 'Rand Hall',
#     'short_name': 'Rand Hall',
#     'types': ['premise']},
#    {'long_name': '921', 'short_name': '921', 'types': ['street_number']},
#    {'long_name': 'University Avenue',
#     'short_name': 'University Ave',
#     'types': ['route']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '14850', 'short_name': '14850', 'types': ['postal_code']}],
#   'formatted_address': 'Rand Hall, 921 University Ave, Ithaca, NY 14850, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 42.4514224, 'lng': -76.4825453},
#     'southwest': {'lat': 42.4507962, 'lng': -76.48485}},
#    'location': {'lat': 42.4512294, 'lng': -76.4836904},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 42.45245828029149,
#      'lng': -76.4823486697085},
#     'southwest': {'lat': 42.4497603197085, 'lng': -76.4850466302915}}},
#   'place_id': 'ChIJufEl8iCC0IkRdFefkYv443Q',
#   'types': ['premise']},
#  {'address_components': [{'long_name': 'FG28+FV',
#     'short_name': 'FG28+FV',
#     'types': ['plus_code']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'FG28+FV Ithaca, NY, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 42.45124999999999,
#      'lng': -76.48275},
#     'southwest': {'lat': 42.451125, 'lng': -76.48287499999999}},
#    'location': {'lat': 42.4512236, 'lng': -76.4828622},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 42.4525364802915,
#      'lng': -76.48146351970848},
#     'southwest': {'lat': 42.4498385197085, 'lng': -76.48416148029149}}},
#   'place_id': 'GhIJeZfmscE5RUARYF7bNuceU8A',
#   'plus_code': {'compound_code': 'FG28+FV Ithaca, NY, USA',
#    'global_code': '87J5FG28+FV'},
#   'types': ['plus_code']},
#  {'address_components': [{'long_name': '882-856',
#     'short_name': '882-856',
#     'types': ['street_number']},
#    {'long_name': 'University Avenue',
#     'short_name': 'University Ave',
#     'types': ['route']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '14850', 'short_name': '14850', 'types': ['postal_code']}],
#   'formatted_address': '882-856 University Ave, Ithaca, NY 14850, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 42.4514183, 'lng': -76.4825038},
#     'southwest': {'lat': 42.4513586, 'lng': -76.4833374}},
#    'location': {'lat': 42.451414, 'lng': -76.4829176},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 42.4527374302915,
#      'lng': -76.4815716197085},
#     'southwest': {'lat': 42.4500394697085, 'lng': -76.48426958029151}}},
#   'place_id': 'ChIJLwhQ8CCC0IkRlLQU_CinS7w',
#   'types': ['route']},
#  {'address_components': [{'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Ithaca, NY, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 42.4670791, 'lng': -76.469803},
#     'southwest': {'lat': 42.41832700000001, 'lng': -76.5269469}},
#    'location': {'lat': 42.4439614, 'lng': -76.5018807},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 42.4670791, 'lng': -76.469803},
#     'southwest': {'lat': 42.41832700000001, 'lng': -76.5269469}}},
#   'place_id': 'ChIJ94iv4IKB0IkRdM5upWgn5Qo',
#   'types': ['locality', 'political']},
#  {'address_components': [{'long_name': '14850',
#     'short_name': '14850',
#     'types': ['postal_code']},
#    {'long_name': 'Ithaca',
#     'short_name': 'Ithaca',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Ithaca, NY 14850, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 42.545595, 'lng': -76.3421429},
#     'southwest': {'lat': 42.2810549, 'lng': -76.6895298}},
#    'location': {'lat': 42.435511, 'lng': -76.5257007},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 42.545595, 'lng': -76.3421429},
#     'southwest': {'lat': 42.2810549, 'lng': -76.6895298}}},
#   'place_id': 'ChIJ8QPrieWA0IkRhMlVx--AuPo',
#   'types': ['postal_code']},
#  {'address_components': [{'long_name': 'Tompkins County',
#     'short_name': 'Tompkins County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Tompkins County, NY, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 42.627419, 'lng': -76.237695},
#     'southwest': {'lat': 42.26297599999999, 'lng': -76.69665499999999}},
#    'location': {'lat': 42.4575747, 'lng': -76.5488232},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 42.627419, 'lng': -76.237695},
#     'southwest': {'lat': 42.26297599999999, 'lng': -76.69665499999999}}},
#   'place_id': 'ChIJPdZvpB-C0IkRoFN9R7uJuuw',
#   'types': ['administrative_area_level_2', 'political']},
#  {'address_components': [{'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'New York, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 45.015861, 'lng': -71.777491},
#     'southwest': {'lat': 40.476578, 'lng': -79.7625901}},
#    'location': {'lat': 43.2994285, 'lng': -74.21793260000001},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 45.015861, 'lng': -71.777491},
#     'southwest': {'lat': 40.476578, 'lng': -79.7625901}}},
#   'place_id': 'ChIJqaUj8fBLzEwRZ5UY3sHGz90',
#   'types': ['administrative_area_level_1', 'political']},
#  {'address_components': [{'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'United States',
#   'geometry': {'bounds': {'northeast': {'lat': 74.071038, 'lng': -66.885417},
#     'southwest': {'lat': 18.7763, 'lng': 166.9999999}},
#    'location': {'lat': 37.09024, 'lng': -95.712891},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 74.071038, 'lng': -66.885417},
#     'southwest': {'lat': 18.7763, 'lng': 166.9999999}}},
#   'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#   'types': ['country', 'political']}]

# %%
## Ta da!
reverse_geocode_result[0]['formatted_address']
# Out:
# '921 University Ave, Ithaca, NY 14850, USA'

# %% [markdown]
# ## 1.3 Getting Points of Interest
# [Google Places API documentation](https://developers.google.com/maps/documentation/places/web-service/overview)

# %%
### The query can be anything you would typically type into
### the google maps search
### radius is in meters
### You can also input the lat/lng directly

places_to_eat = gmaps.places("restaurants",
                             location = "921 University Ave, Ithaca, NY",
                            #  location = (42.4512236,-76.4828622),
                         radius=100)

# %%
places_to_eat.keys()
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
len(places_to_eat['results'])
# Out:
# 20

# %%
places_to_eat['results']
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '130 Statler Dr, Ithaca, NY 14853, United States',
#   'geometry': {'location': {'lat': 42.4464908, 'lng': -76.48222620000001},
#    'viewport': {'northeast': {'lat': 42.44771917989272,
#      'lng': -76.48060872010727},
#     'southwest': {'lat': 42.44501952010727, 'lng': -76.48330837989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Taverna Banfi',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3968,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105202507060282279933">Alice Zhao</a>'],
#     'photo_reference': 'ATplDJZ7OWkbBMoPm6nenVKrWLqQ9P0Jyr2vJ_kzTLmunshOxptvavDtMxr_uUwVh8Ftwy81Zgt4PtW9CnDqQeJ817P3U5BhrTQHPfwa4KzQmsC4SQXBpfMkzWLUSsHUcYgq86tctOAcLoFPi1Ytx6fdgjgGIes_daPHdmzc0CGXAzCxMsWc',
#     'width': 2976}],
#   'place_id': 'ChIJD6RICIuB0IkRJAkwTTcAvLo',
#   'plus_code': {'compound_code': 'CGW9+H4 Ithaca, New York',
#    'global_code': '87J5CGW9+H4'},
#   'price_level': 3,
#   'rating': 4.5,
#   'reference': 'ChIJD6RICIuB0IkRJAkwTTcAvLo',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 179},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '130 Statler Dr, Ithaca, NY 14853, United States',
#   'geometry': {'location': {'lat': 42.4459683, 'lng': -76.4820581},
#    'viewport': {'northeast': {'lat': 42.44761647989272,
#      'lng': -76.48052467010727},
#     'southwest': {'lat': 42.44491682010727, 'lng': -76.48322432989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Mac's Cafe",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109916926979943961401">Ray Zhou</a>'],
#     'photo_reference': 'ATplDJYvw8kclrORyHwRiGNkNim27C0ugzS7ZXyT0-PeF6tYfZvlSHUCFaVNVCqdnZnPvpRHE9yWJU_s6ytEjxKP327biViKBIVBrG6qQ0CBWjfbQMijOoJDGrLwJYPgxcM-qshO0UMqHQVEMit8zb4LTVfSS52LmS91-2E7zB3zMssDpk8g',
#     'width': 1080}],
#   'place_id': 'ChIJzb-1dIuB0IkRGbtEU3S2eUI',
#   'plus_code': {'compound_code': 'CGW9+95 Ithaca, New York',
#    'global_code': '87J5CGW9+95'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJzb-1dIuB0IkRGbtEU3S2eUI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 58},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Sage Ave, Ithaca, NY 14853, United States',
#   'geometry': {'location': {'lat': 42.4458973, 'lng': -76.483245},
#    'viewport': {'northeast': {'lat': 42.44703732989272,
#      'lng': -76.48189782010726},
#     'southwest': {'lat': 42.44433767010727, 'lng': -76.48459747989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Atrium Cafe',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106615294928808839175">Sommaya Haque</a>'],
#     'photo_reference': 'ATplDJb2z6BGpjTtdc0q3GC9sYpZtQacdNMUwU00sQ72PAGfeQZgNATSm0DbZfsvMAa7UPn8834la2ihiDUVWsXHyGYzeuOg95Ts6WK3xF19il1gqJd-EIWqkpPrZ7EGs2sfUP3BHF9EYkei-ZuyP3cLemubZD9VyIb72A1RFB2Hlzs4U3Gz',
#     'width': 3024}],
#   'place_id': 'ChIJxU0lkYuB0IkR48jLemAbYdM',
#   'plus_code': {'compound_code': 'CGW8+9P Ithaca, New York',
#    'global_code': '87J5CGW8+9P'},
#   'rating': 4.1,
#   'reference': 'ChIJxU0lkYuB0IkR48jLemAbYdM',
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 26},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '420 College Ave, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4422194, 'lng': -76.4854036},
#    'viewport': {'northeast': {'lat': 42.44358807989273,
#      'lng': -76.48403687010727},
#     'southwest': {'lat': 42.44088842010728, 'lng': -76.48673652989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Collegetown Bagels',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117882246585235152803">Kevin Canini</a>'],
#     'photo_reference': 'ATplDJaueHBbgEOmLPAfaNLNTTpB6Qpj9mMOayTcsH0T2NHs4RZ2F8VxdfyZJ24ehfQm9YIfqTfZ-FPeyzliQwEwiOc1mirFt8Vj6pIOOHVXFoKy3C8Rrtjm29llHW8giqMIj4dSNWQzRllU4TqVmwCDtrfX_6DcFNAw1r7DkI3DTzRAIdY0',
#     'width': 4048}],
#   'place_id': 'ChIJ-TWeeI6B0IkRCubzG-VVovA',
#   'plus_code': {'compound_code': 'CGR7+VQ Ithaca, New York',
#    'global_code': '87J5CGR7+VQ'},
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'ChIJ-TWeeI6B0IkRCubzG-VVovA',
#   'types': ['bakery',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 1195},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '143 Maple Ave, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4411068, 'lng': -76.4753498},
#    'viewport': {'northeast': {'lat': 42.44250012989272,
#      'lng': -76.47402422010728},
#     'southwest': {'lat': 42.43980047010728, 'lng': -76.47672387989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#   'name': 'Coal Yard Cafe',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2620,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100492706894665710338">Daniel Chow</a>'],
#     'photo_reference': 'ATplDJZO8K-6r8kCn4MHw5KHnR8ff7YhVGlD9diPamMkpR61H_I8rkE5jptxqf_9Y3HurPGJ3Ol95AauFvhUV847opXWh8bAqAxeIEkg4MMakHtIyqngifZecCnV78jb6SXVtIaJ3y8BGbZgPYyxKVhg2-3_BjPjuSyCxRcKK702WJTUGIq5',
#     'width': 4656}],
#   'place_id': 'ChIJOwLVQPKB0IkRr53Xc7-MN_0',
#   'plus_code': {'compound_code': 'CGRF+CV Ithaca, New York',
#    'global_code': '87J5CGRF+CV'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJOwLVQPKB0IkRr53Xc7-MN_0',
#   'types': ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 363},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '709 University Ave, Ithaca, NY 14853, United States',
#   'geometry': {'location': {'lat': 42.44906570000001, 'lng': -76.4894391},
#    'viewport': {'northeast': {'lat': 42.45044137989272,
#      'lng': -76.48809022010727},
#     'southwest': {'lat': 42.44774172010728, 'lng': -76.4907898798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Cook House Dining Room',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118026791443316420245">Ethan R</a>'],
#     'photo_reference': 'ATplDJaLBK6N8K77LLsaYrmfhvUF3JAK8c-jMCOVG-vxLAkrKbD_zMK04yvH-KJEXfIylhex3HrAdoZha5nHxy6B7-upjMWGPw13cw_lEee9XZieHWHbUAJZgl7zeopzaMUMxmQEu3n_wcPNYsLzWa2KNT-wNbPdL3CjkgML76IDyWWpclxf',
#     'width': 3024}],
#   'place_id': 'ChIJf3qLQoiB0IkRES7mfx2mRBU',
#   'plus_code': {'compound_code': 'CGX6+J6 Ithaca, New York',
#    'global_code': '87J5CGX6+J6'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJf3qLQoiB0IkRES7mfx2mRBU',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 64},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '255 Statler Dr, Ithaca, NY 14853, United States',
#   'geometry': {'location': {'lat': 42.4454292, 'lng': -76.4823345},
#    'viewport': {'northeast': {'lat': 42.44677537989272,
#      'lng': -76.48114167010728},
#     'southwest': {'lat': 42.44407572010728, 'lng': -76.48384132989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'The Establishment',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103189978655124004195">张宏鹤</a>'],
#     'photo_reference': 'ATplDJY6c_y31HeUtp1EoDy3X2QKErhgm6Z81uo2uzljAobzZEARTV3vB3NsAacZOpKLA6ttBmEDe4xr8DoVavWMpHm10GopKDdoJNf78pMNok5alyACTyf4CVgvft9aMBuFBf8cD-PH73isCecDBZtp4uLwKbpEnZXVtM24WbeDMO0GON4i',
#     'width': 4048}],
#   'place_id': 'ChIJD6RICIuB0IkRi0ln6iJR1ws',
#   'plus_code': {'compound_code': 'CGW9+53 Ithaca, New York',
#    'global_code': '87J5CGW9+53'},
#   'rating': 4.3,
#   'reference': 'ChIJD6RICIuB0IkRi0ln6iJR1ws',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 7},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '114 W Green St, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.439391, 'lng': -76.49679789999999},
#    'viewport': {'northeast': {'lat': 42.44086837989273,
#      'lng': -76.49486527010727},
#     'southwest': {'lat': 42.43816872010729, 'lng': -76.49756492989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Adam Grill',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105222557694395580876">Heather Lee</a>'],
#     'photo_reference': 'ATplDJb4c2yDP7rnV5TOaKX_WJXJYwxQV0GXuFxinHsoEfg5FnCqIR1ikRiBa8R_a8h89OYjHxH34xlpTr2v25MHjNgLOgMExFf_tf_YrHTIlGS8-ctDjpLhsv_JaTYfStoJFFfeQlm-6aa_81WxyDVBoWvQ99eGqsZYkKFGuMvMSEiVu-rV',
#     'width': 3024}],
#   'place_id': 'ChIJD36mtJ2B0IkRmd1P-2RPuJM',
#   'plus_code': {'compound_code': 'CGQ3+Q7 Ithaca, New York',
#    'global_code': '87J5CGQ3+Q7'},
#   'rating': 4.8,
#   'reference': 'ChIJD36mtJ2B0IkRmd1P-2RPuJM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 108},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '120 S Aurora St, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4392846, 'lng': -76.4957709},
#    'viewport': {'northeast': {'lat': 42.44054407989272,
#      'lng': -76.49424172010727},
#     'southwest': {'lat': 42.43784442010728, 'lng': -76.49694137989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Monks on the Commons',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100512636404916192782">A Google User</a>'],
#     'photo_reference': 'ATplDJam5IzDsLrbWeCeLCs6o1pZyWz7qM-meA501sgM_8V2M79FjsxMFG1crOEG6n9gU1qbFnFxTCfims_OkzXI8dr0NlOU1xSPRhJ_8HLs2EnsyIi86MzIxTdr0lY5OOkKbMcfpjz74MNao1DZoNWFZLN5iYyR-YU-ZWGRLROODRz7v9yq',
#     'width': 4032}],
#   'place_id': 'ChIJ4cdDnpuB0IkR6XZ6ej8U0G4',
#   'plus_code': {'compound_code': 'CGQ3+PM Ithaca, New York',
#    'global_code': '87J5CGQ3+PM'},
#   'price_level': 2,
#   'rating': 3.7,
#   'reference': 'ChIJ4cdDnpuB0IkR6XZ6ej8U0G4',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 160},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '403 College Ave, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4418233, 'lng': -76.4851654},
#    'viewport': {'northeast': {'lat': 42.44316857989272,
#      'lng': -76.48381717010726},
#     'southwest': {'lat': 42.44046892010728, 'lng': -76.48651682989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Dos Amigos',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114298159399816411884">A Google User</a>'],
#     'photo_reference': 'ATplDJbc3xXWbAB3dsn3haBZNTKIcglPoHo8e4F6zD7_-P7qCyjtY-eUg5SQ3ZosDQm4u2Y06McnJij5pnAeeEbWl9PbrCX-fji4iCADYN530F9JX7CTIk9y5Xo-5SAkT98utxnqEbGyXD4xr21ynzTA-ayruSAFO-sl77HScigIImmDis6V',
#     'width': 6000}],
#   'place_id': 'ChIJ-xDLaLB42okR5E1hfT9BVRE',
#   'plus_code': {'compound_code': 'CGR7+PX Ithaca, New York',
#    'global_code': '87J5CGR7+PX'},
#   'rating': 4.3,
#   'reference': 'ChIJ-xDLaLB42okR5E1hfT9BVRE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 165},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '921 University Ave, Ithaca, NY 14853, United States',
#   'geometry': {'location': {'lat': 42.4510294, 'lng': -76.4838846},
#    'viewport': {'northeast': {'lat': 42.45245827989272,
#      'lng': -76.48267367010729},
#     'southwest': {'lat': 42.44975862010727, 'lng': -76.48537332989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Franny's",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1500,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108708170330326627131">A Google User</a>'],
#     'photo_reference': 'ATplDJaLb8HMZg7hjITFlsYcoQd1wQfvYEr2JEufGVJZB7ZJz73Gv_4RYSIiZZnOW3LXOhlQJ40Ri227HG0eprYZlZeHmq-ORDAa6Dfeskegk1W3jNxTSwU9f5ws033g-YQBXn8bfwTaHkM4-wXBI4pR_-zc5N_ecqzq7CP2eVH64Z9eAaE0',
#     'width': 2000}],
#   'place_id': 'ChIJ0a5zwCCC0IkRHWMtFYXPqWY',
#   'plus_code': {'compound_code': 'FG28+CC Ithaca, New York',
#    'global_code': '87J5FG28+CC'},
#   'rating': 4.1,
#   'reference': 'ChIJ0a5zwCCC0IkRHWMtFYXPqWY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 22},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '121 Dryden Rd, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4414861, 'lng': -76.4863859},
#    'viewport': {'northeast': {'lat': 42.44289342989272,
#      'lng': -76.48512687010728},
#     'southwest': {'lat': 42.44019377010728, 'lng': -76.48782652989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Wings Over Ithaca',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2658,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112629661948872166264">juanfelipe2005</a>'],
#     'photo_reference': 'ATplDJZEZTeFW7hNXI7KIcBRKNFbW44TGRxjCM5h4m5iqPEq6Xi0CIBgU4CXdrkhW9KqWP-vsJMXLRxEpDX7do9ig1IeUiUHKLtV5DTKnK5HXvmXYlrQTI1Nc8kg1Uar9C8OuUrzugkrJ1M6Kl3Jr1wMyV3XyEAARefhsnJIQCxy0aytAELX',
#     'width': 2661}],
#   'place_id': 'ChIJ77DKFY6B0IkR43gk5CB_ZaQ',
#   'plus_code': {'compound_code': 'CGR7+HC Ithaca, New York',
#    'global_code': '87J5CGR7+HC'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJ77DKFY6B0IkR43gk5CB_ZaQ',
#   'types': ['meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 381},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '222 E State St, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4397568, 'lng': -76.4958783},
#    'viewport': {'northeast': {'lat': 42.44104647989272,
#      'lng': -76.49445052010728},
#     'southwest': {'lat': 42.43834682010728, 'lng': -76.49715017989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Lev Kitchen',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111685795891293874288">Tanuj Chawla</a>'],
#     'photo_reference': 'ATplDJYqMqNdqg4SAD9-n5nyd2vXNx3jZdQVIOEyIqlD9kAaLXqogjMtbT43Zeu2Vu13aoXGBRJuEOyZlhMtExJJoBxuf4oOKCr9Xxq_m0kVgqOKkgWAEIbpzuD2K7nAsTH-CdFI55nSYvTbv-afVZwK6OSxQSPtj1aAp_TsiBJjQF8f66KB',
#     'width': 3072}],
#   'place_id': 'ChIJsdoK3MOB0IkR1f9RtPqLKeg',
#   'plus_code': {'compound_code': 'CGQ3+WJ Ithaca, New York',
#    'global_code': '87J5CGQ3+WJ'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'ChIJsdoK3MOB0IkR1f9RtPqLKeg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 214},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '315 Eddy St, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4413869, 'lng': -76.48729809999999},
#    'viewport': {'northeast': {'lat': 42.44273587989272,
#      'lng': -76.48598962010728},
#     'southwest': {'lat': 42.44003622010727, 'lng': -76.48868927989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Souvlaki House',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108021009559240828509">Souvlaki House</a>'],
#     'photo_reference': 'ATplDJZyJHs1h4EG8irbxF9iPqt4BWN8ZpI_hZh6L6ksSM9ByqJj-2r2AhUVHc-BcDJLDpHzXtJzSF0-YGtFbkfv9Maaeb1eW0wuuoqboXa6dXEQy7yAZaUdwdQFhELkpbknlCMHsx1aP4IOy9Gm_C5W75KuJ1vtbKy7RRkpCQohDF3rsiw2',
#     'width': 4032}],
#   'place_id': 'ChIJQbGkMI6B0IkRbLvvVimjEjY',
#   'plus_code': {'compound_code': 'CGR7+H4 Ithaca, New York',
#    'global_code': '87J5CGR7+H4'},
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'ChIJQbGkMI6B0IkRbLvvVimjEjY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 328},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '120 Dryden Rd, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4416971, 'lng': -76.4857847},
#    'viewport': {'northeast': {'lat': 42.44300317989273,
#      'lng': -76.48442392010728},
#     'southwest': {'lat': 42.44030352010728, 'lng': -76.48712357989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Jack's Grill",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 664,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111872129310267293666">Jacks Grill</a>'],
#     'photo_reference': 'ATplDJaC-uCmZIUpZ-5kq8C6kAlhNkupaP5a9xk7HdV9X1ItdD9pHm7Gpc04IJGjq01Evo6ywVq7arj8ynyACC7rcEPvnN-dtdeRh8Jw4J0tM7rXCVingbM8b2UECutmewEIMffdd23v0TImatUtI2MMFrIUoGl7GbW0js8h_eTZeOCONLUx',
#     'width': 1000}],
#   'place_id': 'ChIJObP9Q46B0IkRVVNCVZ_Vsno',
#   'plus_code': {'compound_code': 'CGR7+MM Ithaca, New York',
#    'global_code': '87J5CGR7+MM'},
#   'price_level': 2,
#   'rating': 3.3,
#   'reference': 'ChIJObP9Q46B0IkRVVNCVZ_Vsno',
#   'types': ['meal_delivery',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 288},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '208b Dryden Rd, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4417457, 'lng': -76.4846725},
#    'viewport': {'northeast': {'lat': 42.44303792989272,
#      'lng': -76.48334617010728},
#     'southwest': {'lat': 42.44033827010728, 'lng': -76.48604582989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Pho Time Vietnamese Cuisine',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104683485033042215374">Jim Shen</a>'],
#     'photo_reference': 'ATplDJZxohxU4WJiYW_JHE9Im1nRFaT_ukwuPLw00GTWrTDk-t_qsqxXYijYNNJbUuQcMrxseLKnLswySiAYdO7nlFPf_0mwS4PZzlnjXFKkY7GKdDL_w_9wQ9qwUNa_yJZXn2YByOYeXh4eKCZ9RauRnlV7myzeskC_E823PX3QRf3BxZdb',
#     'width': 4000}],
#   'place_id': 'ChIJ1cRs242B0IkR-IgYuB8mbqs',
#   'plus_code': {'compound_code': 'CGR8+M4 Ithaca, New York',
#    'global_code': '87J5CGR8+M4'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJ1cRs242B0IkR-IgYuB8mbqs',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 135},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '408 College Ave, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4419763, 'lng': -76.48541610000001},
#    'viewport': {'northeast': {'lat': 42.44334312989272,
#      'lng': -76.48398982010727},
#     'southwest': {'lat': 42.44064347010728, 'lng': -76.48668947989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'D.P. Dough',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109944215021428932280">DP Dough</a>'],
#     'photo_reference': 'ATplDJa4g6Iz4ZnRcZR7beVhfBauxsXczzDtW9M2IFF9ItGW6kB__FnQXZM_V_umj00TdMhJwGXlyDe3Aiyv8R0vxgxGrHVfu0B-zZ2IUKUj1b3SJu5rjTK7KsmywlIZMBrR-qxtNtExKbP0tpDcpzH928rO2awdpeI7Jf12h0cQsmqTyvgG',
#     'width': 4032}],
#   'place_id': 'ChIJwe2Rdo6B0IkRbak25_BKC0I',
#   'plus_code': {'compound_code': 'CGR7+QR Ithaca, New York',
#    'global_code': '87J5CGR7+QR'},
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'ChIJwe2Rdo6B0IkRbak25_BKC0I',
#   'types': ['meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 316},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Center For Jewish Living, 106 West Ave, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4444948, 'lng': -76.48775690000001},
#    'viewport': {'northeast': {'lat': 42.44584562989272,
#      'lng': -76.48635632010728},
#     'southwest': {'lat': 42.44314597010727, 'lng': -76.48905597989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Cornell Dining',
#   'place_id': 'ChIJlbiG5o6B0IkRH7cLKY7cDIk',
#   'plus_code': {'compound_code': 'CGV6+QV Ithaca, New York',
#    'global_code': '87J5CGV6+QV'},
#   'rating': 4.1,
#   'reference': 'ChIJlbiG5o6B0IkRH7cLKY7cDIk',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 10},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '401 College Ave, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4417167, 'lng': -76.4851229},
#    'viewport': {'northeast': {'lat': 42.44306532989273,
#      'lng': -76.48383827010727},
#     'southwest': {'lat': 42.44036567010728, 'lng': -76.48653792989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Oishii Bowl',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111685795891293874288">Tanuj Chawla</a>'],
#     'photo_reference': 'ATplDJa9trgGvxStylQMEZqsV6wx1gSNeacPTDhB6gBOn1-Ey-C-pJXCGD8jLlQFfwPQE9TqvyoRWB2lKNEnzAN-it2ILfDxpuwHBDbZn6qjC1jzzwk4LRa_FPaEdQPQQl_b5LRo1QsRtcLp68fuc7TFdBjylmMYw2pAmBUX0lO1Kddps0MC',
#     'width': 3072}],
#   'place_id': 'ChIJo8Lj3o2B0IkRM5Lp3TT2GRs',
#   'plus_code': {'compound_code': 'CGR7+MX Ithaca, New York',
#    'global_code': '87J5CGR7+MX'},
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'ChIJo8Lj3o2B0IkRM5Lp3TT2GRs',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 208},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '309 E Lincoln St, Ithaca, NY 14850, United States',
#   'geometry': {'location': {'lat': 42.4519755, 'lng': -76.4969268},
#    'viewport': {'northeast': {'lat': 42.45336237989272,
#      'lng': -76.49558067010727},
#     'southwest': {'lat': 42.45066272010728, 'lng': -76.49828032989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Lincoln Street Diner',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3744,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107926894330150994055">Pouya Samangouei</a>'],
#     'photo_reference': 'ATplDJaf-JiaUpcGOBIby5ADf9S4TCrmIF85DXb-DQG7roekboR4aVGSSmoFNk2q2HL6DnvPT8P4VJbgFqwTLfIPqyhR4qON8yZN6F6tJ93DsqCamhwT1kIipKyM2sBNUFtF40gO1nwZgptnmEL2zoEo4rcj7zG3N_TGlaZGZr8wmBJhBMUV',
#     'width': 7728}],
#   'place_id': 'ChIJoVkB9ymC0IkRrwvsgSBZaJ0',
#   'plus_code': {'compound_code': 'FG23+Q6 Ithaca, New York',
#    'global_code': '87J5FG23+Q6'},
#   'price_level': 1,
#   'rating': 4.7,
#   'reference': 'ChIJoVkB9ymC0IkRrwvsgSBZaJ0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 528}]

# %%
places_to_eat['results'][0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'formatted_address': '130 Statler Dr, Ithaca, NY 14853, United States',
#  'geometry': {'location': {'lat': 42.4464908, 'lng': -76.48222620000001},
#   'viewport': {'northeast': {'lat': 42.44771917989272,
#     'lng': -76.48060872010727},
#    'southwest': {'lat': 42.44501952010727, 'lng': -76.48330837989272}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'name': 'Taverna Banfi',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 3968,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105202507060282279933">Alice Zhao</a>'],
#    'photo_reference': 'ATplDJZ7OWkbBMoPm6nenVKrWLqQ9P0Jyr2vJ_kzTLmunshOxptvavDtMxr_uUwVh8Ftwy81Zgt4PtW9CnDqQeJ817P3U5BhrTQHPfwa4KzQmsC4SQXBpfMkzWLUSsHUcYgq86tctOAcLoFPi1Ytx6fdgjgGIes_daPHdmzc0CGXAzCxMsWc',
#    'width': 2976}],
#  'place_id': 'ChIJD6RICIuB0IkRJAkwTTcAvLo',
#  'plus_code': {'compound_code': 'CGW9+H4 Ithaca, New York',
#   'global_code': '87J5CGW9+H4'},
#  'price_level': 3,
#  'rating': 4.5,
#  'reference': 'ChIJD6RICIuB0IkRJAkwTTcAvLo',
#  'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  'user_ratings_total': 179}

# %%
list_of_restaurants = []

for each in places_to_eat['results']: 
    listing_values = [each['name'],
                      each['geometry']['location']['lng'], 
                      each['geometry']['location']['lat'],
                        each['rating'],
                        each['user_ratings_total'],
                        # each['photos'][0]['photo_reference']
                        ]
    list_of_restaurants.append(listing_values)

# %%
list_of_restaurants
# Out:
# [['Taverna Banfi', -76.48222620000001, 42.4464908, 4.5, 179],
#  ["Mac's Cafe", -76.4820581, 42.4459683, 4.1, 58],
#  ['Atrium Cafe', -76.483245, 42.4458973, 4.1, 26],
#  ['Collegetown Bagels', -76.4854036, 42.4422194, 4.3, 1195],
#  ['Coal Yard Cafe', -76.4753498, 42.4411068, 4.6, 363],
#  ['Cook House Dining Room', -76.4894391, 42.44906570000001, 4.4, 64],
#  ['The Establishment', -76.4823345, 42.4454292, 4.3, 7],
#  ['Adam Grill', -76.49679789999999, 42.439391, 4.8, 108],
#  ['Monks on the Commons', -76.4957709, 42.4392846, 3.7, 160],
#  ['Dos Amigos', -76.4851654, 42.4418233, 4.3, 165],
#  ["Franny's", -76.4838846, 42.4510294, 4.1, 22],
#  ['Wings Over Ithaca', -76.4863859, 42.4414861, 4.1, 381],
#  ['Lev Kitchen', -76.4958783, 42.4397568, 4.5, 214],
#  ['Souvlaki House', -76.48729809999999, 42.4413869, 4.4, 328],
#  ["Jack's Grill", -76.4857847, 42.4416971, 3.3, 288],
#  ['Pho Time Vietnamese Cuisine', -76.4846725, 42.4417457, 4.1, 135],
#  ['D.P. Dough', -76.48541610000001, 42.4419763, 3.9, 316],
#  ['Cornell Dining', -76.48775690000001, 42.4444948, 4.1, 10],
#  ['Oishii Bowl', -76.4851229, 42.4417167, 4.3, 208],
#  ['Lincoln Street Diner', -76.4969268, 42.4519755, 4.7, 528]]

# %%
places_to_eat_df = pd.DataFrame(list_of_restaurants,columns=['name','lng','lat','rating','user_ratings_total'])

# %%
places_to_eat_df
# Out:
#                            name        lng        lat  rating  \
# 0                 Taverna Banfi -76.482226  42.446491     4.5
# 1                    Mac's Cafe -76.482058  42.445968     4.1
# 2                   Atrium Cafe -76.483245  42.445897     4.1
# 3            Collegetown Bagels -76.485404  42.442219     4.3
# 4                Coal Yard Cafe -76.475350  42.441107     4.6
# 5        Cook House Dining Room -76.489439  42.449066     4.4
# 6             The Establishment -76.482334  42.445429     4.3
# 7                    Adam Grill -76.496798  42.439391     4.8
# 8          Monks on the Commons -76.495771  42.439285     3.7
# 9                    Dos Amigos -76.485165  42.441823     4.3
# 10                     Franny's -76.483885  42.451029     4.1
# 11            Wings Over Ithaca -76.486386  42.441486     4.1
# 12                  Lev Kitchen -76.495878  42.439757     4.5
# 13               Souvlaki House -76.487298  42.441387     4.4
# 14                 Jack's Grill -76.485785  42.441697     3.3
# 15  Pho Time Vietnamese Cuisine -76.484673  42.441746     4.1
# 16                   D.P. Dough -76.485416  42.441976     3.9
# 17               Cornell Dining -76.487757  42.444495     4.1
# 18                  Oishii Bowl -76.485123  42.441717     4.3
# 19         Lincoln Street Diner -76.496927  42.451976     4.7
#
#     user_ratings_total
# 0                  179
# 1                   58
# 2                   26
# 3                 1195
# 4                  363
# 5                   64
# 6                    7
# 7                  108
# 8                  160
# 9                  165
# 10                  22
# 11                 381
# 12                 214
# 13                 328
# 14                 288
# 15                 135
# 16                 316
# 17                  10
# 18                 208
# 19                 528

# %%
places_to_eat_df_geo = gpd.GeoDataFrame(places_to_eat_df,
                                        geometry=gpd.points_from_xy(places_to_eat_df['lng'], places_to_eat_df['lat']),
                                        crs='EPSG:4326')

# %%
places_to_eat_df_geo.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b7825174aea586f82421543bb29ab87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b7825174aea586f82421543bb29ab87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b7825174aea586f82421543bb29ab87 = L.map(
#                 &quot;map_5b7825174aea586f82421543bb29ab87&quot;,
#                 {
#                     center: [42.445630050000005, -76.4861383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5b7825174aea586f82421543bb29ab87);
#
#
#
#
#
#             var tile_layer_8b051549925d2824c42506b2649ac62e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8b051549925d2824c42506b2649ac62e.addTo(map_5b7825174aea586f82421543bb29ab87);
#
#
#             map_5b7825174aea586f82421543bb29ab87.fitBounds(
#                 [[42.4392846, -76.4969268], [42.4519755, -76.4753498]],
#                 {}
#             );
#
#
#         function geo_json_54e1e16e580049aa6270198fc3a8bda2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_54e1e16e580049aa6270198fc3a8bda2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_54e1e16e580049aa6270198fc3a8bda2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_54e1e16e580049aa6270198fc3a8bda2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_54e1e16e580049aa6270198fc3a8bda2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_54e1e16e580049aa6270198fc3a8bda2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_54e1e16e580049aa6270198fc3a8bda2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_54e1e16e580049aa6270198fc3a8bda2 = L.geoJson(null, {
#                 onEachFeature: geo_json_54e1e16e580049aa6270198fc3a8bda2_onEachFeature,
#
#                 style: geo_json_54e1e16e580049aa6270198fc3a8bda2_styler,
#                 pointToLayer: geo_json_54e1e16e580049aa6270198fc3a8bda2_pointToLayer,
#         });
#
#         function geo_json_54e1e16e580049aa6270198fc3a8bda2_add (data) {
#             geo_json_54e1e16e580049aa6270198fc3a8bda2
#                 .addData(data);
#         }
#             geo_json_54e1e16e580049aa6270198fc3a8bda2_add({&quot;bbox&quot;: [-76.4969268, 42.4392846, -76.4753498, 42.4519755], &quot;features&quot;: [{&quot;bbox&quot;: [-76.48222620000001, 42.4464908, -76.48222620000001, 42.4464908], &quot;geometry&quot;: {&quot;coordinates&quot;: [-76.48222620000001, 42.4464908], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;lat&quot;: 42.4464908, &quot;lng&quot;: -76.48222620000001, &quot;name&quot;: &quot;Taverna Banfi&quot;, &quot;rating&quot;: 4.5, &quot;user_ratings_total&quot;: 179}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-76.4820581, 42.4459683, -76.4820581, 42.4459683], &quot;geometry&quot;: {&quot;coordinates&quot;: [-76.4820581, 42.4459683], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&q

# %% [markdown]
# ## 1.4 Getting a route and distances
# [Google Directions API documentation](https://developers.google.com/maps/documentation/directions)

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2024, 2, 22, 9, 22, 56, 498727)

# %%
## mode can be driving, walking, bicycling, transit
now = datetime.now()


directions_result = gmaps.directions("921 University Ave, Ithaca, NY",
                                     "Maru Ramen, Ithaca, NY",
                                     mode="driving",
                                     departure_time=now)

# %%
## Notice that this is a list of one elemment
directions_result
# Out:
# [{'bounds': {'northeast': {'lat': 42.4514183, 'lng': -76.4828144},
#    'southwest': {'lat': 42.4393022, 'lng': -76.5068107}},
#   'copyrights': 'Map data ©2024 Google',
#   'legs': [{'distance': {'text': '2.0 mi', 'value': 3220},
#     'duration': {'text': '8 mins', 'value': 477},
#     'duration_in_traffic': {'text': '7 mins', 'value': 428},
#     'end_address': '512 W State St, Ithaca, NY 14850, USA',
#     'end_location': {'lat': 42.4393022, 'lng': -76.5068107},
#     'start_address': '921 University Ave, Ithaca, NY 14853, USA',
#     'start_location': {'lat': 42.4514035, 'lng': -76.4828144},
#     'steps': [{'distance': {'text': '0.5 mi', 'value': 743},
#       'duration': {'text': '2 mins', 'value': 90},
#       'end_location': {'lat': 42.449279, 'lng': -76.4903449},
#       'html_instructions': 'Head <b>west</b> on <b>University Ave</b>',
#       'polyline': {'points': 'ghbbGp`yqMAJAX?\\Bd@JdD@r@FvB@J?N@\\?VAT?h@?N?P?tA@J@H@@BFBFFJHHHHXNdA`@NF`@N`@LDBJD`@VDDTZT\\DHHJR^FLDJBHDF?@@B@@@?Dl@?DFrC?bAAdA?RAhA'},
#       'start_location': {'lat': 42.4514035, 'lng': -76.4828144},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '0.5 mi', 'value': 877},
#       'duration': {'text': '2 mins', 'value': 106},
#       'end_location': {'lat': 42.441573, 'lng': -76.4898149},
#       'html_instructions': 'Turn <b>left</b> onto <b>Stewart Ave</b>',
#       'maneuver': 'turn-left',
#       'polyline': {'points': '_{abGrozqMx@@j@AR?z@?Z?B?fAAH?|AAfBCTAF?LAPCRCHCXEHE|Aa@TIJE@?DAHGDAJIJKHGb@a@DEDEDEBADC@?HCFAFAD?R@~CVv@HF@F@@?B?JBD?d@FJ@HBRDv@V^FR@\\Ab@AhBE'},
#       'start_location': {'lat': 42.449279, 'lng': -76.4903449},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '0.2 mi', 'value': 363},
#       'duration': {'text': '1 min', 'value': 45},
#       'end_location': {'lat': 42.441448, 'lng': -76.4942339},
#       'html_instructions': 'Turn <b>right</b> onto <b>E Buffalo St</b>',
#       'maneuver': 'turn-right',
#       'polyline': {'points': 'yj`bGhlzqM?p@BlB@b@?~B@fA@r@?^@ZB~ABvA?r@BxB?P'},
#       'start_location': {'lat': 42.441573, 'lng': -76.4898149},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '331 ft', 'value': 101},
#       'duration': {'text': '1 min', 'value': 18},
#       'end_location': {'lat': 42.440543, 'lng': -76.4942059},
#       'html_instructions': 'Turn <b>left</b> onto <b>Parker St</b>',
#       'maneuver': 'turn-left',
#       'polyline': {'points': 'aj`bG|g{qMd@?b@Ab@?b@Ab@?'},
#       'start_location': {'lat': 42.441448, 'lng': -76.4942339},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '0.6 mi', 'value': 984},
#       'duration': {'text': '3 mins', 'value': 172},
#       'end_location': {'lat': 42.44018390000001, 'lng': -76.5061779},
#       'html_instructions': 'Turn <b>right</b> onto <b>E Seneca St</b><div style="font-size:0.9em">Pass by M&amp;T Bank (on the left)</div>',
#       'maneuver': 'turn-right',
#       'polyline': {'points': 'kd`bGxg{qM@dAAT?n@A\\@RDl@@z@BrB@tBBxB@~@BfC@v@?^@\\HvIDdEBfB?j@@n@FrFLxL'},
#       'start_location': {'lat': 42.440543, 'lng': -76.4942059},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '315 ft', 'value': 96},
#       'duration': {'text': '1 min', 'value': 24},
#       'end_location': {'lat': 42.439324, 'lng': -76.506134},
#       'html_instructions': 'Turn <b>left</b> onto <b>N Corn St</b>',
#       'maneuver': 'turn-left',
#       'polyline': {'points': 'cb`bGrr}qMjDI'},
#       'start_location': {'lat': 42.44018390000001, 'lng': -76.5061779},
#       'travel_mode': 'DRIVING'},
#      {'distance': {'text': '184 ft', 'value': 56},
#       'duration': {'text': '1 min', 'value': 22},
#       'end_location': {'lat': 42.4393022, 'lng': -76.5068107},
#       'html_instructions': 'Turn <b>right</b> at the 1st cross street onto <b>W State St</b><div style="font-size:0.9em">Destination will be on the right</div>',
#       'maneuver': 'turn-right',
#       'polyline': {'points': 'w|_bGhr}qM?T?\\BrA'},
#       'start_location': {'lat': 42.439324, 'lng': -76.506134},
#       'travel_mode': 'DRIVING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'ghbbGp`yqMCd@BbAV|I?|FH^JRRR~Ap@p@Vf@Pl@\\v@hAj@dAJVHn@FxCAhCA|AdB?nB?vGG|@G`AS`Cq@`@U~@{@TQZGX@vE`@TBbAL\\HvA^~DGDbIDvDJdJ?Pd@?fAAfAA?zAAlAF`AJ~KF~Gl@ll@jDI?TBpB'},
#   'summary': 'Stewart Ave and E Seneca St',
#   'warnings': [],
#   'waypoint_order': []}]

# %%
len(directions_result)
# Out:
# 1

# %% [markdown]
# We can use the `.keys()`

# %%
directions_result[0].keys()
# Out:
# dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])

# %% [markdown]
# Neat! We can see that this has output a lot of different kinds of information. What we'll need next is to parse the information.
#
# Notice that the directions are in `'legs'`. This is the equivalent to each step in Google Map directions. We'll have to put the pieces together to get any information about the whole route.

# %%
## Let's access the first/only element
## and then the values in the legs key
## which is another list
directions_result[0]['legs']
# Out:
# [{'distance': {'text': '2.0 mi', 'value': 3220},
#   'duration': {'text': '8 mins', 'value': 477},
#   'duration_in_traffic': {'text': '7 mins', 'value': 428},
#   'end_address': '512 W State St, Ithaca, NY 14850, USA',
#   'end_location': {'lat': 42.4393022, 'lng': -76.5068107},
#   'start_address': '921 University Ave, Ithaca, NY 14853, USA',
#   'start_location': {'lat': 42.4514035, 'lng': -76.4828144},
#   'steps': [{'distance': {'text': '0.5 mi', 'value': 743},
#     'duration': {'text': '2 mins', 'value': 90},
#     'end_location': {'lat': 42.449279, 'lng': -76.4903449},
#     'html_instructions': 'Head <b>west</b> on <b>University Ave</b>',
#     'polyline': {'points': 'ghbbGp`yqMAJAX?\\Bd@JdD@r@FvB@J?N@\\?VAT?h@?N?P?tA@J@H@@BFBFFJHHHHXNdA`@NF`@N`@LDBJD`@VDDTZT\\DHHJR^FLDJBHDF?@@B@@@?Dl@?DFrC?bAAdA?RAhA'},
#     'start_location': {'lat': 42.4514035, 'lng': -76.4828144},
#     'travel_mode': 'DRIVING'},
#    {'distance': {'text': '0.5 mi', 'value': 877},
#     'duration': {'text': '2 mins', 'value': 106},
#     'end_location': {'lat': 42.441573, 'lng': -76.4898149},
#     'html_instructions': 'Turn <b>left</b> onto <b>Stewart Ave</b>',
#     'maneuver': 'turn-left',
#     'polyline': {'points': '_{abGrozqMx@@j@AR?z@?Z?B?fAAH?|AAfBCTAF?LAPCRCHCXEHE|Aa@TIJE@?DAHGDAJIJKHGb@a@DEDEDEBADC@?HCFAFAD?R@~CVv@HF@F@@?B?JBD?d@FJ@HBRDv@V^FR@\\Ab@AhBE'},
#     'start_location': {'lat': 42.449279, 'lng': -76.4903449},
#     'travel_mode': 'DRIVING'},
#    {'distance': {'text': '0.2 mi', 'value': 363},
#     'duration': {'text': '1 min', 'value': 45},
#     'end_location': {'lat': 42.441448, 'lng': -76.4942339},
#     'html_instructions': 'Turn <b>right</b> onto <b>E Buffalo St</b>',
#     'maneuver': 'turn-right',
#     'polyline': {'points': 'yj`bGhlzqM?p@BlB@b@?~B@fA@r@?^@ZB~ABvA?r@BxB?P'},
#     'start_location': {'lat': 42.441573, 'lng': -76.4898149},
#     'travel_mode': 'DRIVING'},
#    {'distance': {'text': '331 ft', 'value': 101},
#     'duration': {'text': '1 min', 'value': 18},
#     'end_location': {'lat': 42.440543, 'lng': -76.4942059},
#     'html_instructions': 'Turn <b>left</b> onto <b>Parker St</b>',
#     'maneuver': 'turn-left',
#     'polyline': {'points': 'aj`bG|g{qMd@?b@Ab@?b@Ab@?'},
#     'start_location': {'lat': 42.441448, 'lng': -76.4942339},
#     'travel_mode': 'DRIVING'},
#    {'distance': {'text': '0.6 mi', 'value': 984},
#     'duration': {'text': '3 mins', 'value': 172},
#     'end_location': {'lat': 42.44018390000001, 'lng': -76.5061779},
#     'html_instructions': 'Turn <b>right</b> onto <b>E Seneca St</b><div style="font-size:0.9em">Pass by M&amp;T Bank (on the left)</div>',
#     'maneuver': 'turn-right',
#     'polyline': {'points': 'kd`bGxg{qM@dAAT?n@A\\@RDl@@z@BrB@tBBxB@~@BfC@v@?^@\\HvIDdEBfB?j@@n@FrFLxL'},
#     'start_location': {'lat': 42.440543, 'lng': -76.4942059},
#     'travel_mode': 'DRIVING'},
#    {'distance': {'text': '315 ft', 'value': 96},
#     'duration': {'text': '1 min', 'value': 24},
#     'end_location': {'lat': 42.439324, 'lng': -76.506134},
#     'html_instructions': 'Turn <b>left</b> onto <b>N Corn St</b>',
#     'maneuver': 'turn-left',
#     'polyline': {'points': 'cb`bGrr}qMjDI'},
#     'start_location': {'lat': 42.44018390000001, 'lng': -76.5061779},
#     'travel_mode': 'DRIVING'},
#    {'distance': {'text': '184 ft', 'value': 56},
#     'duration': {'text': '1 min', 'value': 22},
#     'end_location': {'lat': 42.4393022, 'lng': -76.5068107},
#     'html_instructions': 'Turn <b>right</b> at the 1st cross street onto <b>W State St</b><div style="font-size:0.9em">Destination will be on the right</div>',
#     'maneuver': 'turn-right',
#     'polyline': {'points': 'w|_bGhr}qM?T?\\BrA'},
#     'start_location': {'lat': 42.439324, 'lng': -76.506134},
#     'travel_mode': 'DRIVING'}],
#   'traffic_speed_entry': [],
#   'via_waypoint': []}]

# %%
len(directions_result[0]['legs'])
# Out:
# 1

# %%
directions_result[0]['legs'][0]['steps']
# Out:
# [{'distance': {'text': '0.5 mi', 'value': 743},
#   'duration': {'text': '2 mins', 'value': 90},
#   'end_location': {'lat': 42.449279, 'lng': -76.4903449},
#   'html_instructions': 'Head <b>west</b> on <b>University Ave</b>',
#   'polyline': {'points': 'ghbbGp`yqMAJAX?\\Bd@JdD@r@FvB@J?N@\\?VAT?h@?N?P?tA@J@H@@BFBFFJHHHHXNdA`@NF`@N`@LDBJD`@VDDTZT\\DHHJR^FLDJBHDF?@@B@@@?Dl@?DFrC?bAAdA?RAhA'},
#   'start_location': {'lat': 42.4514035, 'lng': -76.4828144},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '0.5 mi', 'value': 877},
#   'duration': {'text': '2 mins', 'value': 106},
#   'end_location': {'lat': 42.441573, 'lng': -76.4898149},
#   'html_instructions': 'Turn <b>left</b> onto <b>Stewart Ave</b>',
#   'maneuver': 'turn-left',
#   'polyline': {'points': '_{abGrozqMx@@j@AR?z@?Z?B?fAAH?|AAfBCTAF?LAPCRCHCXEHE|Aa@TIJE@?DAHGDAJIJKHGb@a@DEDEDEBADC@?HCFAFAD?R@~CVv@HF@F@@?B?JBD?d@FJ@HBRDv@V^FR@\\Ab@AhBE'},
#   'start_location': {'lat': 42.449279, 'lng': -76.4903449},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '0.2 mi', 'value': 363},
#   'duration': {'text': '1 min', 'value': 45},
#   'end_location': {'lat': 42.441448, 'lng': -76.4942339},
#   'html_instructions': 'Turn <b>right</b> onto <b>E Buffalo St</b>',
#   'maneuver': 'turn-right',
#   'polyline': {'points': 'yj`bGhlzqM?p@BlB@b@?~B@fA@r@?^@ZB~ABvA?r@BxB?P'},
#   'start_location': {'lat': 42.441573, 'lng': -76.4898149},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '331 ft', 'value': 101},
#   'duration': {'text': '1 min', 'value': 18},
#   'end_location': {'lat': 42.440543, 'lng': -76.4942059},
#   'html_instructions': 'Turn <b>left</b> onto <b>Parker St</b>',
#   'maneuver': 'turn-left',
#   'polyline': {'points': 'aj`bG|g{qMd@?b@Ab@?b@Ab@?'},
#   'start_location': {'lat': 42.441448, 'lng': -76.4942339},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '0.6 mi', 'value': 984},
#   'duration': {'text': '3 mins', 'value': 172},
#   'end_location': {'lat': 42.44018390000001, 'lng': -76.5061779},
#   'html_instructions': 'Turn <b>right</b> onto <b>E Seneca St</b><div style="font-size:0.9em">Pass by M&amp;T Bank (on the left)</div>',
#   'maneuver': 'turn-right',
#   'polyline': {'points': 'kd`bGxg{qM@dAAT?n@A\\@RDl@@z@BrB@tBBxB@~@BfC@v@?^@\\HvIDdEBfB?j@@n@FrFLxL'},
#   'start_location': {'lat': 42.440543, 'lng': -76.4942059},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '315 ft', 'value': 96},
#   'duration': {'text': '1 min', 'value': 24},
#   'end_location': {'lat': 42.439324, 'lng': -76.506134},
#   'html_instructions': 'Turn <b>left</b> onto <b>N Corn St</b>',
#   'maneuver': 'turn-left',
#   'polyline': {'points': 'cb`bGrr}qMjDI'},
#   'start_location': {'lat': 42.44018390000001, 'lng': -76.5061779},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '184 ft', 'value': 56},
#   'duration': {'text': '1 min', 'value': 22},
#   'end_location': {'lat': 42.4393022, 'lng': -76.5068107},
#   'html_instructions': 'Turn <b>right</b> at the 1st cross street onto <b>W State St</b><div style="font-size:0.9em">Destination will be on the right</div>',
#   'maneuver': 'turn-right',
#   'polyline': {'points': 'w|_bGhr}qM?T?\\BrA'},
#   'start_location': {'lat': 42.439324, 'lng': -76.506134},
#   'travel_mode': 'DRIVING'}]

# %% [markdown]
# We can get the total time and distance that it took:
# - `directions_result[0]['legs'][0]['steps'][i]['distance']` gives us the distance of that leg
# - `directions_result[0]['legs'][0]['steps'][i]['duration']` gives us the duration of that leg

# %%
distance_list = []
duration_list = []
for each in directions_result[0]['legs'][0]['steps']: 
    ## Here we are going to get the 'value' after the 'distance' key. 
    ## For the distance, this is given in meters
    # # The duration is in seconds.  
    distance_list.append(each['distance']['value'])
    duration_list.append(each['duration']['value'])

# %%
print(distance_list)
print(duration_list)
# Out:
# [743, 877, 363, 101, 984, 96, 56]
# [90, 106, 45, 18, 172, 24, 22]

# %% [markdown]
# Now, we can create a df, where each row could include the distance, duration, and (eventually) the route geometry
#
# First, we'll need a list with the sums of each of the `duration_list` and `distance_list`.

# %%
## Note that, because pandas takes each element in the list as a row,
## We need to wrap the list in another list
summed_route_data = [[sum(distance_list),sum(duration_list)]]

# %%
summed_route_data
# Out:
# [[3220, 477]]

# %%
477/60
# Out:
# 7.95

# %% [markdown]
# Then, we'll need a list of the respective column names

# %%
col_names = ['distance','duration']

# %%
routes = pd.DataFrame(summed_route_data,
                      columns=col_names)

# %%
routes
# Out:
#    distance  duration
# 0      3220       477

# %% [markdown]
# Turning the polyline string into points. Note that Google Maps includes an encoded version of, in this case, a polyline, which we can turn back into a shapely geometry.
#
# I found this function online to help me do this. `get_linestring()` takes a Google encoded polyline and turns it into a geometry, using the `decode_polyline()` function. Don't worry too much about what `decode_polyline()` is doing, except that some helpful person has created a decoder for us to use.

# %%
import json
import fiona
import pandas as pd
from shapely.geometry import LineString, mapping, shape

def decode_polyline(polyline_str):
    '''Pass a Google Maps encoded polyline string; returns list of lat/lon pairs'''
    index, lat, lng = 0, 0, 0
    coordinates = []
    changes = {'latitude': 0, 'longitude': 0}

    # Coordinates have variable length when encoded, so just keep
    # track of whether we've hit the end of the string. In each
    # while loop iteration, a single coordinate is decoded.
    while index < len(polyline_str):
        # Gather lat/lon changes, store them in a dictionary to apply them later
        for unit in ['latitude', 'longitude']: 
            shift, result = 0, 0

            while True:
                byte = ord(polyline_str[index]) - 63
                index+=1
                result |= (byte & 0x1f) << shift
                shift += 5
                if not byte >= 0x20:
                    break

            if (result & 1):
                changes[unit] = ~(result >> 1)
            else:
                changes[unit] = (result >> 1)

        lat += changes['latitude']
        lng += changes['longitude']

        coordinates.append((lng / 100000.0, lat / 100000.0))

    return coordinates

def get_linestring(data):
    # with open(trip_name + '.json', 'r') as data_file:    
    #     data = json.load(data_file, encoding='ISO-8859-1')

    the_points = []
    for step in data[0]['legs'][0]['steps']:
        the_points += decode_polyline(step['polyline']['points'])

    return LineString(the_points)

# %%
## Here, I am getting the linestring from the directions result
geom = shape(mapping(get_linestring(directions_result)))

# %%
geom
# Out:
# <LINESTRING (-76.483 42.451, -76.483 42.451, -76.483 42.451, -76.483 42.451,...>

# %%
routes['geom']=geom

# %%
routes_geo =gpd.GeoDataFrame(routes, geometry='geom', crs='EPSG:4326')

# %%
routes_geo
# Out:
#    distance  duration                                               geom
# 0      3220       477  LINESTRING (-76.48281 42.45140, -76.48287 42.4...

# %% [markdown]
# Chaning to 3857 because it looks better.

# %%
routes_geo_3857 = routes_geo.to_crs(epsg=3857)

# %%
routes_geo_3857.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fed7bfa933536e3f6121ef6314532d58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fed7bfa933536e3f6121ef6314532d58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fed7bfa933536e3f6121ef6314532d58 = L.map(
#                 &quot;map_fed7bfa933536e3f6121ef6314532d58&quot;,
#                 {
#                     center: [42.44536, -76.49481],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fed7bfa933536e3f6121ef6314532d58);
#
#
#
#
#
#             var tile_layer_c811c2b2d323b97c0bc92955671bcf32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c811c2b2d323b97c0bc92955671bcf32.addTo(map_fed7bfa933536e3f6121ef6314532d58);
#
#
#             map_fed7bfa933536e3f6121ef6314532d58.fitBounds(
#                 [[42.4393, -76.50681], [42.45142, -76.48281]],
#                 {}
#             );
#
#
#         function geo_json_3ff13e45f66a3bf0f5d959b067731053_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3ff13e45f66a3bf0f5d959b067731053_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3ff13e45f66a3bf0f5d959b067731053_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3ff13e45f66a3bf0f5d959b067731053_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3ff13e45f66a3bf0f5d959b067731053_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_3ff13e45f66a3bf0f5d959b067731053.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3ff13e45f66a3bf0f5d959b067731053_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3ff13e45f66a3bf0f5d959b067731053 = L.geoJson(null, {
#                 onEachFeature: geo_json_3ff13e45f66a3bf0f5d959b067731053_onEachFeature,
#
#                 style: geo_json_3ff13e45f66a3bf0f5d959b067731053_styler,
#                 pointToLayer: geo_json_3ff13e45f66a3bf0f5d959b067731053_pointToLayer,
#         });
#
#         function geo_json_3ff13e45f66a3bf0f5d959b067731053_add (data) {
#             geo_json_3ff13e45f66a3bf0f5d959b067731053
#                 .addData(data);
#         }
#             geo_json_3ff13e45f66a3bf0f5d959b067731053_add({&quot;bbox&quot;: [-76.50681, 42.4393, -76.48281, 42.45142], &quot;features&quot;: [{&quot;bbox&quot;: [-76.50681, 42.4393, -76.48281, 42.45142], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-76.48281, 42.4514], [-76.48287, 42.451409999999996], [-76.48299999999999, 42.45142], [-76.48315, 42.45142], [-76.48333999999998, 42.4514], [-76.48416999999999, 42.45134], [-76.48443, 42.45133], [-76.48503, 42.45129], [-76.48508999999999, 42.45128], [-76.48517, 42.45128], [-76.48532, 42.451269999999994], [-76.48544, 42.451269999999994], [-76.48555, 42.45128], [-76.48576, 42.45128], [-76.48583999999998, 42.45128], [-76.48592999999998, 42.45128], [-76.48636, 42.45128], [-76.48641999999998, 42.451269999999994], [-76.48647, 42.45126], [-76.48647999999999, 42.45125], [-76.48652, 42.45123], [-76.48656, 42.45121], [-76.486619

# %% [markdown]
# ## Q.2 Routing
# - Create a geodataframe with one row that describes the walking route from the **Johnson Art Museum** to the **Purity Ice Cream Co.**
# - This gdf should have the following columns: start lng,start lat, start name, end lng, end lat, end name, geometry for the route, walking distance in kilometers, walking duration in minutes.

# %%
## INSERT YOUR CODE HERE
now = datetime.now()

directions_result = gmaps.directions("Johnson Art Museum, Ithaca, NY",
                                     "Purity Ice Cream, Ithaca, NY",
                                     mode="walking",
                                     departure_time=now)

distance_list = []
duration_list = []

for each in directions_result[0]['legs'][0]['steps']: 
    distance_list.append(each['distance']['value'])
    duration_list.append(each['duration']['value'])

dist = sum(distance_list)/1000
duration = sum(duration_list)/60

# %%
start_address = directions_result[0]["legs"][0]['start_address']
start_lat = directions_result[0]["legs"][0]['start_location']['lat']
start_lng =directions_result[0]["legs"][0]['start_location']['lng']

end_address = directions_result[0]["legs"][-1]['end_address']
end_lat = directions_result[0]["legs"][-1]['end_location']['lat']
end_lng =directions_result[0]["legs"][-1]['end_location']['lng']

# %%
col_names = ['start_lng', 'start_lat', 'start_name', 'end_lng', 'end_lat', 'end_name', 'distance','duration']
routes = pd.DataFrame([[start_lng, start_lat, "Johnson Museum of Art", end_lng, end_lat, "Purity Ice Cream Co.", dist, duration]],
                      columns=col_names)

# %%
routes
# Out:
#    start_lng  start_lat             start_name    end_lng    end_lat  \
# 0 -76.485818  42.450693  Johnson Museum of Art -76.508731  42.444314
#
#                end_name  distance  duration
# 0  Purity Ice Cream Co.     2.757      36.8

# %%
geom = shape(mapping(get_linestring(directions_result)))
routes['geom']=geom
routes_geo =gpd.GeoDataFrame(routes, geometry='geom', crs='EPSG:4326')

# %%
routes_geo.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46144b388d0c8e0d3410d92d603bbd5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46144b388d0c8e0d3410d92d603bbd5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46144b388d0c8e0d3410d92d603bbd5c = L.map(
#                 &quot;map_46144b388d0c8e0d3410d92d603bbd5c&quot;,
#                 {
#                     center: [42.446685, -76.497235],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_46144b388d0c8e0d3410d92d603bbd5c);
#
#
#
#
#
#             var tile_layer_436ceb5f8f87abc8303c45ff06951876 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_436ceb5f8f87abc8303c45ff06951876.addTo(map_46144b388d0c8e0d3410d92d603bbd5c);
#
#
#             map_46144b388d0c8e0d3410d92d603bbd5c.fitBounds(
#                 [[42.44268, -76.50873], [42.45069, -76.48574]],
#                 {}
#             );
#
#
#         function geo_json_4113b90bcaa40ae4253189a586b4a469_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4113b90bcaa40ae4253189a586b4a469_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4113b90bcaa40ae4253189a586b4a469_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4113b90bcaa40ae4253189a586b4a469_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4113b90bcaa40ae4253189a586b4a469_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_4113b90bcaa40ae4253189a586b4a469.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4113b90bcaa40ae4253189a586b4a469_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4113b90bcaa40ae4253189a586b4a469 = L.geoJson(null, {
#                 onEachFeature: geo_json_4113b90bcaa40ae4253189a586b4a469_onEachFeature,
#
#                 style: geo_json_4113b90bcaa40ae4253189a586b4a469_styler,
#                 pointToLayer: geo_json_4113b90bcaa40ae4253189a586b4a469_pointToLayer,
#         });
#
#         function geo_json_4113b90bcaa40ae4253189a586b4a469_add (data) {
#             geo_json_4113b90bcaa40ae4253189a586b4a469
#                 .addData(data);
#         }
#             geo_json_4113b90bcaa40ae4253189a586b4a469_add({&quot;bbox&quot;: [-76.50873, 42.44268, -76.48574, 42.45069], &quot;features&quot;: [{&quot;bbox&quot;: [-76.50873, 42.44268, -76.48574, 42.45069], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-76.48582, 42.45069], [-76.4858, 42.45063], [-76.48577, 42.45056], [-76.48575, 42.45043], [-76.48574, 42.45038], [-76.4858, 42.45026], [-76.48586, 42.45013], [-76.4859, 42.45006], [-76.48592, 42.44988], [-76.48593, 42.44985], [-76.4859, 42.44971], [-76.4859, 42.44971], [-76.48609, 42.4497], [-76.48622, 42.44971], [-76.48633, 42.44971], [-76.48656, 42.4497], [-76.48666, 42.44969], [-76.48669, 42.44968], [-76.48678, 42.44967], [-76.48691, 42.44964], [-76.48693, 42.44963], [-76.48708, 42.44957], [-76.48715, 42.44956], [-76.48722, 42.44954], [-76.48739, 42.44953], [-76.48761, 42.44964], [-76.48761, 42.44964], [-76.487

# %% [markdown]
# ## 1.4 Billing
# Note that the Geocoder is **billed by usage**. Here is the pricing model:
# </figure>
# <img src="https://www.dropbox.com/s/jqmy92vncaar573/Screen%20Shot%202023-02-19%20at%205.50.16%20PM.png?dl=1" alt="drawing" width="1000" style="display: block; margin: 0 auto"/>
# </figure>
#
#
# Think carefully about what you are querying and pay attention to your usage. Don't use up all your credits!

# %% [markdown]
# # 2. OPTIONAL: `beautifulsoup`
#
# Webscraping is a method of programmatically retrieving data from websites. It is used when there are no APIs or when data that is published from the website isn't made avaliable in a downloadable format.
#
# #### A note on webscrapping (and why I generally avoid it):
# Webscrapping can be used for all kinds of malicious purposes, for instance, to copy website content and republish it. Here's a [complaint from Craiglist](https://www.scribd.com/doc/313832868/CraigslistVRadpad-Complaint?secret_password=7gTybamKvrbeVhxfi4mx) about a company called Radpad scraping Craigslist and reposting those listing on their own website:
#
# <mark>
# “[The content scraping service] would, on a daily basis, send an army of digital robots to craigslist to copy and download the full text of millions of craigslist user ads. [The service] then indiscriminately made those misappropriated listings available—through its so-called ‘data feed’—to any company that wanted to use them, for any purpose. Some such ‘customers’ paid as much as $20,000 per month for that content…”</mark>
# <br>
# <br>
#
# <mark>
# According to the claim, scraped data was used for spam and email fraud, among other activities: </mark>
# <br>
# <br>
#
# <mark>
# “[The defendants] then harvest craigslist users’ contact information from that database, and initiate many thousands of electronic mail messages per day to the addresses harvested from craigslist servers…. [The messages] contain misleading subject lines and content in the body of the spam messages, designed to trick craigslist users into switching from using craigslist’s services to using [the defenders’] service…”
# </mark>
# <br>
# <br>
#
# Uff.
#
# **What about webscrapping for research or academic purposes?** Most of the above issues most likely won't apply to you, but webscrapping makes a website's traffic *spike* if you don't modulate how often you're pinging the website. This can cause the website's server to crash. This is not very nice. Also, a lot of websites won't allow you to do it. (If you go to almost any URL and put `/robots.txt` after it, you can see a list of subdomains that site will or won't allow you to scrape.)

# %% [markdown]
# The first step is to install Beautiful Soup. You can install it using pip by running the following command in your terminal:

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\desai\miniforge3\envs\crp4680\lib\site-packages (from beautifulsoup4) (2.5)

# %% [markdown]
# Once you have installed Beautiful Soup, the next step is to import the required libraries in your Python script:

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Here, we are importing BeautifulSoup from the bs4 library, which we will use to parse the HTML data we scrape from a website. We are also importing `requests`, which we will use to send HTTP requests to the website and retrieve the HTML data.
#
# The next step is to send a request to the website and retrieve the HTML data. You can do this using the `requests.get()` method, which takes the website URL as a parameter and returns the HTML content of the website.

# %%
## This is the SF Craigslist page for apartments. 
url = 'https://www.century21.com/real-estate/ithaca-ny/LCNYITHACA/'
response = requests.get(url)

# %% [markdown]
# Once we have retrieved the HTML data, the next step is to parse it using Beautiful Soup. We can do this by creating a BeautifulSoup object and passing the HTML data as a parameter.
#
# The second parameter `'html.parser'` specifies the parser to use for parsing the HTML data. In this case, we are using the built-in HTML parser that comes with Beautiful Soup.

# %%
soup = BeautifulSoup(response.text, 'html.parser',)

# %% [markdown]
# We can print soup and see what it looks like. It's essentially all the HTML served on a website:

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html data-usagetrack-config='{"clickDefault": "ga-event", "viewDefault": "ga-event", "viewOnReady": true}' lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="minimum-scale=1.0, width=device-width, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="Ithaca Real Estate | Find Houses &amp; Homes for Sale in Ithaca, NY" name="title"/>
# <meta content="Search Ithaca real estate property listings to find homes for sale in Ithaca, NY. Browse houses for sale in Ithaca today!" name="description">
# <meta content="Ithaca real estate, Ithaca homes, Ithaca homes for sale, Ithaca properties, Ithaca listings, Ithaca houses for sale, NY real estate, NY homes, NY homes for sale, NY properties, NY listings, NY houses for sale" name="keywords">
# <title>Ithaca Real Estate | Find Houses &amp; Homes for Sale in Ithaca, NY</title>
# <link href="https://www.century21.com/real-estate/ithaca-ny/LCNYITHACA/" hreflang="en-US" rel="alternate"/>
# <link href="https://espanol.century21.com/propiedades-en-venta/ithaca-ny/LCNYITHACA/" hreflang="es" rel="alternate"/>
# <link href="https://www.century21.com/real-estate/ithaca-ny/LCNYITHACA/" rel="canonical"/>
# <link href="https://www.century21.com/real-estate/ithaca-ny/LCNYITHACA/?s=20" rel="next"/>
# <link href="/images/apple/manifest.json" rel="manifest"/>
# <link color="#252526" href="/images/apple/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/images/apple/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/apple/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/images/apple/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/apple/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/images/apple/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/apple/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/images/apple/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/apple/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/images/apple/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/images/apple/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="/images/apple/favicon-160x160.png" rel="icon" sizes="160x160" type="image/png"/>
# <link href="/images/apple/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/images/apple/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/images/apple/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <meta content="#00a300" name="msapplication-TileColor"/>
# <meta content="#ffc40d" name="msapplication-TileColor"/>
# <meta content="/images/apple/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <script>
#       (function(d) {
#          var config = {
#             kitId: 'gxn4oaa',
#             scriptTimeout: 3000,
#             async: true
#          },
#          h=d.documentElement,t=setTimeout(function(){h.className=h.className.replace(/\bwf-loading\b/g,"")+" wf-inactive";},config.scriptTimeout),tk=d.createElement("script"),f=false,s=d.getElementsByTagName("script")[0],a;h.className+=" wf-loading";tk.src='https://use.typekit.net/'+config.kitId+'.js';tk.async=true;tk.onload=tk.onreadystatechange=function(){a=this.readyState;if(f||a&&a!="complete"&&a!="loaded")return;f=true;clearTimeout(t);try{Typekit.load(config)}catch(e){}};s.parentNode.insertBefore(tk,s)
#       })(document);
#    </script>
# <script>
#       /*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
#       !(function(a){"use strict";var b=function(b,c,d){function e(a){return h.body?a():void setTimeout(function(){e(a)})}function f(){i.addEventListener&&i.removeEventListener("load",f),i.media=d||"all"}var g,h=a.document,i=h.createElement("link");if(c)g=c;else{var j=(h.body||h.getElementsByTagName("head")[0]).childNodes;g=j[j.length-1]}var k=h.styleSheets;i.rel="stylesheet",i.href=b,i.media="only x",e(function(){g.parentNode.insertBefore(i,c?g:g.nextSibling)});var l=function(a){for(var b=i.href,c=k.length;c--;)if(k[c].href===b)return a();setTimeout(function(){l(a)})};return i.addEventListener&&i.addEventListener("load",f),i.onloadcssdefined=l,l(f),i};"undefined"!=typeof exports?exports.loadCSS=b:a.loadCSS=b}("undefined"!=typeof global?global:this));
#       /*! loadCSS rel=preload polyfill. [c]2017 Filament Group, Inc. MIT License */
#       !(function(a){if(a.loadCSS){var b=loadCSS.relpreload={};if(b.support=function(){try{return a.document.createElement("link").relList.supports("preload")}catch(b){return!1}},b.poly=function(){for(var b=a.document.getElementsByTagName("link"),c=0;c<b.length;c++){var d=b[c];"preload"===d.rel&&"style"===d.getAttribute("as")&&(a.loadCSS(d.href,d,d.getAttribute("media")),d.rel=null)}},!b.support()){b.poly();var c=a.setInterval(b.poly,300);a.addEventListener&&a.addEventListener("load",function(){b.poly(),a.clearInterval(c)}),a.attachEvent&&a.attachEvent("onload",function(){a.clearInterval(c)})}}}(this));
#    </script>
# <script>
#
#          loadCSS('/css/c21/search.css?__VERSION=020820241425');
#
#          loadCSS('/css/modals/mortgageCalc.css?__VERSION=020820241425');
#
#       loadCSS('/css/newLayout.css?__VERSION=020820241425');
#       loadCSS('/css/searchbox.css?__VERSION=020820241425');
#       loadCSS('/css/freetextsearch.css?__VERSION=020820241425');
#       loadCSS('/css/_phonePortal.css?__VERSION=020820241425', null, 'screen and (max-width: 767px)');
#       loadCSS('/css/_tabletPortal.css?__VERSION=020820241425', null, 'screen and (min-width: 768px) and (max-width: 983px)');
#    </script>
# <noscript>
# <link href="/css/c21/search.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/mortgageCalc.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/newLayout.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/searchbox.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/freetextsearch.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/_phonePortal.css?__VERSION=020820241425" media="screen and (max-width: 767px)" rel="stylesheet"/>
# <link href="/css/_tabletPortal.css?__VERSION=020820241425" media="screen and (min-width: 768px) and (max-width: 983px)" rel="stylesheet"/>
# </noscript>
# <script src="/js/c21/require.js"></script>
# <script>
#       requirejs.config({waitSeconds:0,baseUrl:"/js/c21/",paths:{
#          jquery:"/js/c21/jquery-1.12.3",waypoints:"/js/c21/jquery.waypoints",newPortal:"/js/newPortal",jquerybbq:"/js/c21/jquery.ba-bbq",jquerybrowser:"/js/c21/jquery.browser",jqueryaddplaceholder:"/js/jqueryPlugins/jquery.addplaceholder",jquerycolor:"/js/jqueryPlugins/jquery.color",jqueryui:"/js/jqueryPlugins/jqueryui/jquery-ui-1.8.23.custom",jqueryuiwidget:"/js/jqueryPlugins/jqueryui/jquery.ui.widget",jquerybadform:"/js/jqueryPlugins/jquery.badform",jqueryenter:"/js/jqueryPlugins/jquery.enter",carousel:"/js/c21/carouselPanel",portalSearch:"/js/portalSearch",newPortalSearch:"/js/newPortalSearch",portalAjax:"/js/portalAjax",bbq:"/js/jqueryPlugins/jquery.ba-bbq",cookie:"/js/jqueryPlugins/jquery.cookie",track:"/js/track",usageTrack:"/js/usage-track",myc21:"/js/myc21",slick:"/js/c21/charts/slick",intl:"/js/Internationalization",tli:"/js/TallLoadingIndicator",c21helpers:"/js/c21Helpers",chartMaster:"/js/c21/charts/ChartMaster",chartGroup:"/js/c21/charts/ChartGroup",portalform:"/js/PortalForm",pageform:"/js/PageForm",lazyLoad:"/js/lazyLoad",modalWindows:"/js/modalWindows",portalExtensions:"/js/portalExtensions",freeTextSearch:"/js/freeTextSearch",contactForms:"/js/contactForms",portalParams:"/js/PortalParams",listHub:"/js/listhub",maps:"/js/c21/maps",mapAndDirections:"/js/c21/mapAndDirections",rewriteRules:"/js/RewriteEngine",ouical:"/js/c21/third-party/ouical",addToCalendar: '/js/c21/addToCalendar',photoswipe:"/js/c21/third-party/photoswipe/photoswipe",photoswipeui:"/js/c21/third-party/photoswipe/photoswipe-ui-default",malihu:"/js/c21/jquery.mCustomScrollbar",mediacarousel:"/js/c21/mediacarousel",mediathumbnails:"/js/c21/mediathumbnails",calculators:"/js/c21/calculators",formValidator:"/js/formValidator",videojs:"https://vjs.zencdn.net/6.6.3/video"},shim:{calculators:{deps:["modalWindows"],exports:"MortgageCalculator"},xdr:{deps:["jquery"]},jquerycolor:{deps:["jquery"]},slick:{deps:["jquery"]},malihu:{deps:["jquery"]},jquerybadform:{deps:["jquery"]},portalParams:{exports:"portalParams",deps:["rewriteRules"]},contactForms:{exports:"contactForms",deps:["portalform","myc21","LoadingIndicator"]},freeTextSearch:{exports:"freeTextSearch"},jqueryenter:{deps:["jquery"]},jqueryui:{deps:["jquery"]},jqueryuiwidget:{deps:["jquery","jqueryui"]},jqueryaddplaceholder:{deps:["jquery"]},portalExtensions:{deps:["jqueryaddplaceholder","jqueryuiwidget"],exports:"cyberFormUtility"},modalWindows:{deps:["portalAjax","portalExtensions"],exports:"modalWindows"},lazyLoad:{deps:["jquery"],exports:"ImageLazyLoader"},portalform:{deps:["modalWindows","jqueryenter"],exports:"PortalForm"},c21helpers:{exports:"c21Helpers"},intl:{exports:"g_internationalization"},myc21:{deps:["portalform","pageform","portalAjax","lazyLoad"],exports:"myc21"},track:{deps:["jquery","intl","c21helpers"],exports:"Track"},usageTrack:{deps:["jquery","track"],exports:"usagetrack"},cookie:{deps:["jquery"]},bbq:{deps:["jquery","jquerybrowser"]},portalAjax:{deps:["jquery","bbq","cookie","freeTextSearch","portalParams","jquerybadform"],exports:"portalAjax"},newPortalSearch:{deps:["jquery","portalAjax","tli","newPortal"]},portalSearch:{deps:["newPortalSearch"],exports:"portalSearch"},newPortal:{deps:["jquery","track","myc21"],exports:"locationManager"},waypoints:{deps:["jquery"],exports:"Waypoint"},infinite:{deps:["waypoints","jquery"]},jquery:{exports:["$","jQuery"]},jquerybbq:{deps:["jquery","jquerybrowser"],exports:"jQuery.param.fragment"},jquerybrowser:{deps:["jquery"],exports:"jQuery.browser"},jquerybuildingblocksanalytics:{deps:["jquery"],exports:"jquerybuildingblocksanalytics"},formValidator:{deps:["jquery"],exports:"formValidator"},videojs:{exports:['videojs']}}});
#     </script>
# <!--[if lte IE 10]>
#    <script defer>require(['xdr']);</script>
#    <![endif]-->
# <script>
#          (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#          })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#          document.addEventListener("DOMContentLoaded", function() {
#             require(['track'], function(Track) {
#                Track.includeFunctionalTag(function() {
#                   ga('create', 'UA-7095058-1', {'cookieDomain': '.century21.com'});
#                   ga('send', 'pageview');
#                }, true);
#             });
#          });
#       </script>
# <script>
#       require(['track'], function(Track) {
#          Track.includeFunctionalTag(function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#             s.async = true;
#             s.defer = true;
#             s.src = (document.location.protocol == "https:" ? "https://" : "http://") + "tracking.listhub.net/scripts/la.js";
#             el.parentNode.insertBefore(s, el);
#          });
#       });
#    </script>
# <script>
#       window.m_aDeferredMethods = [];window.defer = function (fn) {   (window.m_aDeferredMethods) ? window.m_aDeferredMethods.push(fn) : fn();};document.domain=function(){var a=document.location.host.split(".");return a[a.length-2]+".com"}();window.websiteCode = 'RES';defer(function () { myc21.setFacebookAppId('113564428714357') });window.bingMapInitialized = false;function globalBingMapsReady() {	window.bingMapInitialized = true;	$(document).trigger('bingMapsLoaded');}
#    </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#            j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#            'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#    })(window,document,'script','dataLayer','GTM-53DP8T5');</script>
# <!-- End Google Tag Manager -->
# <style class="critical-css">
#
#
#          /* Generated from URL /real-estate/chandler-az/LCAZCHANDLER/?pdp=REN050960041 */
# @media (max-width: 767px) {
#     *, ::after, ::before { box-sizing: inherit; }
#     html { box-sizing: border-box; }
#     body, html { height: 100%; }
#     * * { margin: 0px; }
#     .Smaller, body { font-weight: 400; }
#     body { line-height: 1.7em; font-family: Oakes, Helvetica, Arial, sans-serif; font-size: 12px; color: rgb(56, 56, 58); background-size: cover; background-color: rgb(255, 255, 255); background-attachment: fixed; background-position: center top; }
#     html #modalContainer #modalShadowWrapper.nonPropertyContactWrapper, html #modalContainer #modalShadowWrapper.propertyContactWrapper, html body { background-color: rgb(255, 255, 255); }
#     body.gallery-view, body.map-view { background-color: rgb(255, 255, 255); }
#     #truste-consent-track { border: 1px solid rgb(230, 231, 232); padding: 15px; background-color: rgb(230, 231, 232); direction: ltr; bottom: 0px; min-width: 99%; position: fixed !important; }
#     .truste-messageColumn { font-family: "Adelle Sans", sans-serif; font-size: 14px; color: rgb(255, 255, 255); margin: 15px 0px; float: none; }
#     #truste-consent-text { color: rgb(37, 37, 38); font-size: 14px; margin: 0px 0px 10px; }
#     a { text-decoration: none; color: rgb(95, 85, 68); }
#     body.gallery-view a, body.map-view a { text-decoration: none; }
#     #truste-privacy-button { color: rgb(81, 115, 148); text-decoration: underline; }
#     .truste-buttonsColumn { float: none; margin: 10px 0px 0px; font-size: 15px; font-family: "Adelle Sans", sans-serif; }
#     .btn, body button, body.content-page #PageBody.Standard1Lane .contentBreadcrumbs, body.error #PageBody.Standard1Lane .contentBreadcrumbs, body.res .calculator3Lane #BodyCenterLane .LaneTitle.TitleColspan { font-family: Typold, Helvetica, Arial, sans-serif; }
#     #truste-show-consent { background-color: transparent; color: rgb(37, 37, 38); border: 1px solid rgb(37, 37, 38); padding: 5px 10px; border-radius: 4px; cursor: pointer; font-family: "Adelle Sans", sans-serif; font-size: 14px; display: block; width: 95%; margin: 0px auto; }
#     #truste-consent-button, #truste-consent-required { background-color: rgb(190, 175, 135); color: rgb(37, 37, 38); padding: 5px 10px; border: 1px solid rgb(190, 175, 135); border-radius: 4px; cursor: pointer; font-family: "Adelle Sans", sans-serif; font-size: 14px; display: block; width: 95%; margin: 5px auto; }
#     .site-header { position: static; z-index: 5; top: 0px; left: 0px; right: 0px; transition: background-color 0.3s ease 0s, box-shadow 0.3s ease 0s; }
#     body.prp .site-header { position: static; }
#     .site-header .header-main-bar { font-family: Typold, Helvetica, Arial, sans-serif; background-color: rgb(37, 37, 38); width: 100%; display: flex; position: relative; align-items: flex-start; height: 111px; z-index: 99; }
#     body#srp .header-main-bar, body.home #site-footer { z-index: 5; }
#     .site-header .header-main-bar .logo { vertical-align: top; height: 60px; display: inline-block; }
#     .site-header a { color: rgb(190, 175, 135); text-decoration: none; }
#     .site-header .header-main-bar .logo a { background-image: url("/images/portal/Century21-logo.svg"), linear-gradient(transparent, transparent); display: block; height: inherit; width: 127px; text-indent: -9999px; margin-right: 15px; margin-left: 19px; margin-top: 3px; background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar .right-nav { margin-left: auto; display: flex; margin-right: 19px; align-items: center; padding-top: 26px; }
#     .site-header .header-main-bar .right-nav .nav-item { margin-right: 1.5em; }
#     .site-header .header-main-bar .right-nav .header-account-button { height: 12px; width: 12px; cursor: pointer; position: relative; }
#     #site-footer .deco-logo svg, .site-header .header-main-bar .header-main-nav .sister-sites .deco-logo svg, .site-header .header-main-bar .right-nav .nav-item svg { fill: rgb(190, 175, 135); }
#     .site-header .header-main-bar #account-dropdown { display: none; }
#     .h3, h3 { font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; font-size: 16px; }
#     #FooterLegal, #FooterTopMarkets, .btn { text-align: center; }
#     .btn, .btn .svg-inline { vertical-align: middle; }
#     .btn, .close { font-weight: 700; cursor: pointer; }
#     #PageBreadcrumbs .C2msBlock, #PageBreadcrumbs .C2msSection, .btn { display: inline-block; }
#     .btn { letter-spacing: 1.6px; text-transform: uppercase; font-size: 10px; padding: 0.25em 0.75em; text-decoration: none; background-color: transparent; border: 1px solid transparent; margin: 0.5em 0.5em 0.5em 0px; min-height: 27px; transition: color 0.15s ease-in-out 0s, background-color 0.15s ease-in-out 0s, border-color 0.15s ease-in-out 0s, box-shadow 0.15s ease-in-out 0s; font-family: Typold, Helvetica, Arial, sans-serif; font-weight: 700; display: inline-block; text-align: center; vertical-align: middle; cursor: pointer; }
#     .btn-orange { background-color: rgb(255, 255, 255); color: rgb(190, 175, 135); border: 1px solid rgb(190, 175, 135); }
#     body.res .btn-orange { color: rgb(56, 56, 58); border: 1px solid rgb(190, 175, 135); background-position: 0px 0px; }
#     .btn-primary { color: rgb(56, 56, 58); background-color: rgb(190, 175, 135); border-color: rgb(190, 175, 135); }
#     #HeaderLoggedIn { display: none; }
#     .site-header .header-main-bar .right-nav .nav-item a { color: rgb(190, 175, 135) !important; }
#     .site-header .header-main-bar .right-nav .header-chat { height: 12px; width: 12px; cursor: pointer; }
#     .sr-only { position: absolute; width: 1px; height: 1px; padding: 0px; overflow: hidden; clip: rect(0px, 0px, 0px, 0px); white-space: nowrap; border: 0px; }
#     .site-header .sr-only { color: rgb(255, 255, 255); }
#     .hidden-md-down { display: none; }
#     .site-header .header-main-bar .right-nav .header-phone { font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; font-size: 13px; }
#     .site-header .header-main-bar .navbar-toggle { display: none; position: absolute; left: -100%; top: -100%; }
#     .site-header .header-main-bar .navbar-toggle + label { font-size: 25px; margin-top: 24px; padding-right: 15px; -webkit-font-smoothing: antialiased; cursor: pointer; }
#     .site-header .header-main-bar nav { display: none; font-weight: 400; position: relative; background-color: rgb(37, 37, 38); width: 100%; margin-top: 40px; }
#     .site-header .header-main-bar nav .header-mega { display: table; padding: 20px 18px 15px 15px; width: 100%; background-color: rgb(61, 57, 53); }
#     .site-header .header-main-bar nav .header-mega .header-mega-label { display: inline-block; text-transform: uppercase; position: relative; padding-right: 2px; margin-left: 2px; font-size: 14px; letter-spacing: 1.6px; color: rgb(255, 255, 255); cursor: pointer; }
#     .site-header .header-main-bar nav .header-mega .header-mega-menu { display: none; width: 100%; position: absolute; left: 0px; top: 79px; min-height: 220px; z-index: 1000001; box-shadow: rgba(0, 0, 0, 0.5) 0px 3px 5px -2px; }
#     .btn-gold { background-color: rgb(190, 175, 135); color: rgb(0, 0, 0); }
#     body.res .btn-gold { background-color: rgb(190, 175, 135); color: rgb(37, 37, 38) !important; }
#     .h4, h4 { font-family: TypoldExtended, Typold, Helvetica, Arial, sans-serif; font-size: 10px; }
#     .fadeInDown { animation-name: fadeInDown; }
#     .force-small-caps { font-size: 1em; }
#     .site-header .header-main-bar nav .header-mega.more-menu-toggle { display: none; }
#     .site-header .header-main-bar nav .header-mega.more-menu-toggle .header-mega-label { color: rgb(190, 175, 135); }
#     .site-header .header-main-bar .header-main-nav .sister-sites { position: relative; }
#     body:not(.home) .deco-logo { display: none; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .deco-logo { width: 75px; height: 75px; position: absolute; right: 15px; top: -39px; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .nav { padding: 15px; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .nav a { font-family: Typold, Helvetica, Arial, sans-serif; text-transform: uppercase; font-size: 14px; display: block; padding: 20px 0px; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .nav-bottom { display: flex; padding: 0px 15px 15px; align-items: center; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .header-phone { font-size: 20px; font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; }
#     .social-icons { padding: 1em 0px; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .social-icons { margin-left: auto; }
#     .social-icons .social-icon { display: inline-block; height: 19px; width: 19px; margin-right: 16px; text-indent: -9999px; background-size: contain !important; padding-right: 14px; }
#     .social-icons .social-icon-youtube { background-image: url("/images/portal/ionicons-youtube.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .social-icons .social-icon-youtube { background-image: url("/images/portal/ionicons-youtube-gold.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .social-icons .social-icon a { display: block; height: inherit; width: inherit; text-indent: -9999px; }
#     .social-icons .social-icon-twitter { background-image: url("/images/portal/ionicons-twitter.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .social-icons .social-icon-twitter { background-image: url("/images/portal/ionicons-twitter-gold.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .social-icons .social-icon-facebook { background-image: url("/images/portal/ionicons-facebook.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .social-icons .social-icon-facebook { background-image: url("/images/portal/ionicons-facebook-gold.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .social-icons .social-icon-instagram { background-image: url("/images/portal/ionicons-instagram.svg"), linear-gradient(transparent, transparent); padding-right: 0px; background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .social-icons .social-icon-instagram { background-image: url("/images/portal/ionicons-instagram-gold.svg"), linear-gradient(transparent, transparent); padding-right: 0px; background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar .header-main-nav .sister-sites .social-icons .social-icon:last-child { margin-right: 0px; }
#     .site-header .header-main-bar #dropdown-homepage-container .search-toggle { width: 15px; height: 15px; display: none; position: absolute; right: 100px; top: 0px; margin: 35px 0px 0px; background-image: url("/images/portal/icon_search.svg"), linear-gradient(transparent, transparent); background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar #dropdown-homepage-container .search-toggle .search-label { display: none; }
#     #dropdown { position: relative; width: 666px; top: 42px; left: 159px; z-index: 1; }
#     html #dropdown { left: auto; width: 96%; margin: 0px 2%; }
#     .site-header .header-main-bar #dropdown { margin: 0px; width: auto; position: absolute; right: 15px; top: 63px; left: 13px; max-width: none; }
#     #dropdownSearchBox { height: 66px; }
#     html #dropdownSearchBox { background-color: rgb(153, 153, 153); box-shadow: rgb(102, 102, 102) 0px 0px 0px 1px; border: 1px solid rgb(204, 204, 204); border-radius: 2px; box-sizing: border-box; }
#     .site-header .header-main-bar #dropdownSearchBox { position: relative; background-color: rgb(255, 255, 255); width: 210px; height: 27px; border-radius: 0px; overflow: hidden; }
#     .site-header .header-main-bar #dropdown #dropdownSearchBox { width: 100%; box-shadow: none; border: 0px; }
#     .site-header .header-main-bar #dropdownSearchBox label { position: absolute; left: 6px; top: 6px; font-weight: 300; color: rgb(56, 56, 58); }
#     .searchText { font-size: 16px; line-height: 20px; color: rgb(133, 133, 133); outline: 0px; }
#     #dropdown .searchText { margin: 0px; top: 24px; left: 27px; position: absolute; background-image: url("/images/clear.gif"); background-color: transparent; border: none; width: 480px; height: 20px; }
#     html #dropdown .searchText { background-color: rgb(255, 255, 255); height: 40px; top: 13px; left: 13px; width: 64.5%; padding-left: 3%; margin-right: 1%; font-size: 13px; border: 1px solid rgb(102, 102, 102); box-shadow: rgb(187, 187, 187) 0px 0px 10px inset; box-sizing: border-box; }
#     .site-header .header-main-bar #dropdown .searchText { top: 0px; left: 0px; width: calc(100% - 26px); font-size: 12px; line-height: 26px; height: 26px; box-sizing: border-box; padding-left: 8px; background-color: rgb(255, 255, 255); }
#     .site-header .header-main-bar #dropdown #behindSearchText { color: rgb(89, 89, 89); -webkit-text-fill-color: rgb(89, 89, 89); background-color: rgb(255, 255, 255); }
#     .site-header .header-main-bar #dropdown #dropdownSearchBox input.searchText { border: 0px; box-shadow: none; background-position: 0px 0px; }
#     #searchText.searchValue { color: rgb(0, 0, 0); }
#     .site-header .header-main-bar #dropdown .ftsClear { position: absolute; top: 6px; right: 37px; outline: 0px; width: 15px; height: 15px; border: none; line-height: 15px; padding: 0px; cursor: pointer; background-image: url("/images/portal/black-clear-search.svg"), linear-gradient(transparent, transparent); background-size: 15px 15px; background-position: 0px center, 0px center; background-repeat: no-repeat no-repeat; }
#     .site-header .header-main-bar #dropdownSearchBox #searchButton { position: absolute; right: 0px; top: 0px; background-color: rgb(190, 175, 135); background-image: url("/images/portal/find.svg"), linear-gradient(transparent, transparent); border: none; height: 27px; width: 32px; cursor: pointer; background-size: 15px; background-position: center center, center center; background-repeat: no-repeat no-repeat; }
#     #dropdownResults { position: absolute; top: 60px; width: 666px; overflow: hidden; }
#     html #dropdownResults, html #innerSearch, html .agentResultsDiv, html .locationResultsDiv, html .officeResultsDiv, html .propertyResultsDiv { width: 100%; }
#     body .site-header #dropdown-homepage-container #dropdownResults, body.error .search-section .homepage-main-search #dropdownResults, body.home .homepage-bottom .homepage-main-search #dropdownResults { right: auto; width: auto; top: auto; font-size: 12px; }
#     .site-header .header-main-bar #dropdown #dropdownResults { left: -13px; right: -15px; }
#     body .site-header #dropdown-homepage-container #dropdownResults #dropdownRepeat, body .site-header #dropdown-homepage-container #dropdownResults #dropdownResultsBottom, body .site-header #dropdown-homepage-container #dropdownResults #dropdownResultsTop, body .site-header #dropdown-homepage-container #dropdownResults #dropdownSearchContent, body.error .search-section .homepage-main-search #dropdownResults #dropdownRepeat, body.error .search-section .homepage-main-search #dropdownResults #dropdownResultsBottom, body.error .search-section .homepage-main-search #dropdownResults #dropdownResultsTop, body.error .search-section .homepage-main-search #dropdownResults #dropdownSearchContent, body.home .homepage-bottom .homepage-main-search #dropdownResults #dropdownRepeat, body.home .homepage-bottom .homepage-main-search #dropdownResults #dropdownResultsBottom, body.home .homepage-bottom .homepage-main-search #dropdownResults #dropdownResultsTop, body.home .homepage-bottom .homepage-main-search #dropdownResults #dropdownSearchContent { display: none; background-position: 0px 0px; }
#     #dropdownContent { display: none; }
#     html #dropdownContent { padding: 0px; border: 1px solid rgb(119, 119, 119); background-color: rgb(238, 238, 238); }
#     body .site-header #dropdown-homepage-container #dropdownResults #dropdownContent, body.error .search-section .homepage-main-search #dropdownResults #dropdownContent, body.home .homepage-bottom .homepage-main-search #dropdownResults #dropdownContent { padding: 0px; background-color: rgb(255, 255, 255); border: none; box-shadow: rgba(0, 0, 0, 0.2) 0px 1px 1px; }
#     .site-header .header-main-bar .fha-link { position: absolute; top: 90px; right: 14px; font-size: 9px; display: block; color: rgb(255, 255, 255) !important; }
#     #prop-search-container { position: absolute; inset: 80px 0px 0px; height: auto; top: 100px; }
#     #filters-container { height: inherit; background-color: rgb(255, 255, 255); position: relative; z-index: 4; font-weight: 100; font-family: Oakes, Helvetica, Arial, sans-serif; color: rgb(203, 203, 203); border-bottom-width: 1px; border-bottom-style: solid; border-bottom-color: rgb(203, 203, 203); padding: 12px 0px 14px; box-sizing: border-box; display: none; }
#     #filters-container .search-filter { width: 10.5%; text-align: left; min-width: 73px; cursor: pointer; display: inline-block; vertical-align: middle; color: rgb(83, 83, 77); position: relative; }
#     #filters-container .filter-location { background-image: url("/images/c21/propsearch/pin.svg"), linear-gradient(transparent, transparent); box-sizing: border-box; min-width: 130px; background-position: 10px 3px; background-repeat: no-repeat no-repeat; max-width: 20.5%; }
#     #filters-container div#filter-baths, #filters-container div#filter-beds, #filters-container div#filter-price, #filters-container div.search-filter { width: auto; }
#     #filters-container .search-filter.filter-active { color: rgb(83, 83, 83); }
#     #filters-container #filter-location { white-space: nowrap; overflow: hidden; text-overflow: ellipsis; padding: 5px 20px 5px 28px; margin-left: 10px; }
#     #filters-container .search-filter .filter-box { position: absolute; bottom: 0px; left: 12px; right: 12px; border-bottom-width: 1px; border-bottom-style: dotted; border-bottom-color: rgb(204, 204, 204); }
#     #filters-container .search-filter .filter-label { margin-left: 10px; margin-right: 16px; }
#     #filters-container #filter-location .filter-label { margin-left: 0px; }
#     .filter-price, .filter-select { position: relative; display: inline-block; cursor: pointer; }
#     #filters-container #filter-baths, #filters-container #filter-beds, #filters-container #filter-languages, #filters-container #filter-more, #filters-container #filter-price, #filters-container #filter-specialties { position: relative; padding: 5px 0px; }
#     #filters-container #filter-price { width: 15%; }
#     #filters-container #filter-price .filter-label { white-space: nowrap; overflow: hidden; text-overflow: ellipsis; display: block; }
#     .filter-price-options, .filter-select-options { display: none; position: absolute; top: 25px; z-index: 10000; background-color: rgb(248, 248, 248); box-shadow: rgba(0, 0, 0, 0.6) 0px 3px 5px -2px; width: 100%; padding: 8px; line-height: 20px; }
#     #filters-container #filter-price .filter-price-options { display: none; }
#     #filters-container #filter-baths, #filters-container #filter-beds { width: 8%; }
#     #filters-container div#filter-more { width: 8%; margin-left: 10px; font-weight: 400; position: relative; background-image: url("/images/c21/propsearch/slider-tool.svg"), linear-gradient(transparent, transparent); padding-left: 18px; background-position: 0px 4px; background-repeat: no-repeat no-repeat; border-right-style: none; }
#     #filters-container div#filter-more .filter-box { left: 0px; right: 8px; }
#     #filters-container .filter-input { position: relative; border: 1px solid rgb(203, 203, 203); }
#     #filters-container .search-filter.filter-input { cursor: text; width: 165px; text-align: left; margin: 0px 20px 0px 15px; overflow: hidden; }
#     #filters-container div.search-filter.filter-input { width: 145px; }
#     #filters-container #filter-keyword, #filters-container #filter-name { height: 25px; }
#     #filters-container .filter-input .filter-label { position: relative; top: 3px; }
#     #filters-container #filter-view { vertical-align: text-top; border-right-style: none; position: absolute; right: 0px; width: auto; top: 7px; margin-right: 10px; z-index: 1; }
#     #filters-container .search-filter div.filter-container { display: inline-flex; flex-direction: row-reverse; align-items: baseline; width: 53px; height: 42px; font-family: Typold, Helvetica, Arial, sans-serif; font-size: 10px; letter-spacing: 1.6px; }
#     #filters-container .search-filter div.filter-container div.map-background { background-image: url("/images/c21/propsearch/view-map.svg"), linear-gradient(transparent, transparent); display: block; width: 11px; height: 22px; margin: 0px auto; position: relative; background-position: 0px 11px; background-repeat: no-repeat no-repeat; }
#     #filters-container .search-filter div.filter-container div + div { width: 41px; height: 20px; border: none; background-color: rgb(255, 255, 255); text-transform: uppercase; outline: 0px; cursor: pointer; padding-left: 7px; padding-top: 2px; }
#     body.gallery-view #gallery-view-button .grid-background { top: 11px; background-position: 0px -11px !important; }
#     #filters-container .search-filter div.filter-container div.grid-background { background-image: url("/images/c21/propsearch/view-grid.svg"), linear-gradient(transparent, transparent); display: block; width: 11px; height: 22px; margin: 0px auto; position: relative; background-position: 0px 11px; background-repeat: no-repeat no-repeat; }
#     body.gallery-view #gallery-view-button div + div { font-weight: 600; }
#     #filters-container #filters-expanded-location, #filters-container #filters-expanded-more { display: none; background-color: rgb(255, 255, 255); }
#     #filters-container #filters-expanded-location { padding: 20px; position: relative; top: 20px; width: 100%; background-color: rgb(251, 250, 250); border-top-width: 1px; border-top-style: solid; border-top-color: rgb(211, 211, 211); border-bottom-width: 1px; border-bottom-style: solid; border-bottom-color: rgb(211, 211, 211); height: 360px; }
#     #filters-container #filters-expanded-more { top: 20px; position: relative; box-sizing: border-box; background-color: rgb(251, 250, 250); width: 100%; border-top-width: 1px; border-top-style: solid; border-top-color: rgb(199, 199, 199); }
#     #filters-container #filters-additional { display: none; background-color: rgb(255, 255, 255); clear: both; top: 0px; position: relative; overflow: hidden; height: 0px; }
#     #full-width-container { inset: 56px 0px 0px; position: absolute; background-color: rgb(255, 255, 255); top: 129px; }
#     body.gallery-view #full-width-container { position: static; inset: auto; }
#     body.arp #full-width-container, body.orp #full-width-container, body.prp.gallery-view #full-width-container { background-color: rgb(242, 244, 245); }
#     #results-container { width: 384px; float: right; height: 100%; position: relative; overflow: hidden scroll; color: rgb(63, 63, 63); display: none; }
#     .gallery-view #results-container { display: block; }
#     body.gallery-view #results-container, body.map-view #results-container { width: 100%; }
#     body.gallery-view #results-container { overflow: visible; float: none; position: static; height: auto; width: 100%; }
#     #results-container > div { height: 100%; }
#     .gallery-view #results-container #results-parent { overflow: hidden; }
#     .gallery-view #results-container .filter-wrap { background-color: rgb(255, 255, 255); display: flex; align-items: baseline; margin-bottom: 3em; }
#     #results-container .results-label { padding: 9px 0px 0px 12px; width: 62%; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; text-align: left; padding-left: 12px; }
#     .gallery-view #results-container .results-label { width: 100%; box-sizing: border-box; }
#     body.gallery-view #results-container .results-label { padding: 15px 150px 12px 12px; padding-right: 12px; }
#     .gallery-view #results-container .filter-wrap .results-label { width: auto; padding: 15px 32px 12px 12px; }
#     .h1, .h2, h1, h2 { font-family: TypoldCondensed, Typold, Helvetica, Arial, sans-serif; }
#     .h1, h1 { font-size: 34px; line-height: 1em; }
#     #results-container .results-label h1 { font-family: Oakes, Helvetica, Arial, sans-serif; font-size: 12px; font-weight: 400; display: inline; letter-spacing: normal; }
#     .gallery-view #results-container .results-label h1 { font-size: 16px; }
#     body.gallery-view #action-save-search, body.gallery-view #sort-order { display: none; }
#     #results-container #sort-order { color: rgb(132, 114, 82); font-size: 12px; padding-left: 12px; text-align: left; }
#     body.gallery-view #results-container #sort-order { padding-left: 12px; margin-bottom: 1.8em; }
#     .gallery-view #results-container .filter-wrap #sort-order { margin-bottom: 0px; }
#     #results-container #sort-order .filter-select { color: rgb(63, 63, 63); width: 150px; }
#     #results-container #sort-order .filter-select .filter-select-value { color: rgb(132, 114, 82); }
#     #results-container #action-save-search { position: relative; float: right; margin-top: -34px; }
#     .gallery-view #results-container .filter-wrap #action-save-search { margin-left: auto; margin-top: 0px; }
#     .gallery-view .infinite-container { margin: 0px auto; text-align: center; width: 100%; }
#     .clearfix { display: block; zoom: 1; clear: both; }
#     #BodyClear, #FooterClear, .clearfix { clear: both; }
#     #results-container .property-card { position: relative; font-family: Typold, Helvetica, Arial, sans-serif; border-bottom-width: 1px; border-bottom-style: solid; border-bottom-color: rgb(221, 221, 221); overflow: hidden; cursor: pointer; background-color: rgb(255, 255, 255); box-shadow: rgba(0, 0, 0, 0.16) 0px 3px 6px 0px; margin: 5px 0px; width: 384px; }
#     body.gallery-view #results-container .property-card { width: 100%; }
#     body.gallery-view #results-container .property-card .property-card-clip { float: left; height: 79%; width: 36%; min-width: 136px; margin: 12px 10px 0px 12px; }
#     #results-container .property-card .property-card-image { height: 155px; width: 200px; margin: 12px 10px 12px 12px; overflow: hidden; float: left; position: relative; background-size: cover; background-position: center center; background-repeat: no-repeat no-repeat; }
#     body.gallery-view #results-container .property-card .property-card-image { height: 133px; width: 100%; margin: 0px; position: relative; background-size: cover; background-position: center center; background-repeat: no-repeat no-repeat; }
#     .property-image-flag { z-index: 1; text-transform: uppercase; position: absolute; top: 0px; left: 0px; line-height: 19px; padding: 3px 12px 0px; font-family: Oakes, Helvetica, Arial, sans-serif; font-size: 9px; }
#     .property-image-flag.open-house { background-color: rgb(190, 175, 135); color: rgb(37, 37, 38); }
#     .pdp-open .property-image-flag { z-index: 1; }
#     body.prp .property-image-flag { z-index: auto; }
#     #results-container .property-card .property-image-count { font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; position: absolute; bottom: 7px; left: 7px; color: rgb(255, 255, 255); font-size: 10px; background-color: rgba(0, 0, 0, 0.6); width: 38px; }
#     #results-container .property-card .property-image-count .image-count-current, #results-container .property-card .property-image-count .image-count-left, #results-container .property-card .property-image-count .image-count-right { display: none; }
#     #results-container .property-card .property-image-count .image-count-total { padding-left: 18px; background-image: url("/images/c21/propsearch/photo.svg"), linear-gradient(transparent, transparent); position: relative; left: 3px; bottom: 0px; background-position: 1px 4px; background-repeat: no-repeat no-repeat; }
#     #results-container .property-card .property-card-primary-info { position: relative; font-size: 12px; color: rgb(107, 109, 113); height: 100%; width: 143px; float: left; text-align: left; line-height: 18px; }
#     body.gallery-view #results-container .property-card .property-card-primary-info { width: 45%; }
#     .pdp-listing-type { font-weight: 700; font-size: 15px; margin-bottom: 10px; margin-left: 0px; }
#     #results-container .pdp-listing-type { font-size: 0.9em; color: rgb(87, 87, 87); }
#     body.gallery-view #results-container .pdp-listing-type { font-weight: 700; font-size: 11px; position: relative; margin: 8px 0px 3px; top: 0px; }
#     #results-container .property-card .listing-price { color: rgb(132, 114, 82); font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; text-decoration: none; font-size: 24px; display: inline-block; font-weight: 100; padding-top: 2px; margin-left: -1px; }
#     [class*="col-"] { padding-left: 15px; padding-right: 15px; position: relative; width: 100%; flex-grow: 1; flex-shrink: 0; }
#     .col-wrap-last, .col-wrap-mid { padding: 0px !important; }
#     body.gallery-view .col-wrap-last, body.gallery-view .col-wrap-mid { min-height: 30px; }
#     #results-container .property-card .property-card-primary-info strong { font-size: 13px; font-weight: 700; color: rgb(63, 63, 63); }
#     #results-container .property-card .property-address-info { line-height: 13px; padding-top: 5px; }
#     #results-container .property-card .property-address { color: rgb(63, 63, 63); font-size: 11px; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; width: 150px; }
#     body.gallery-view #results-container .property-card .property-card-primary-info .property-address { width: 100%; }
#     #results-container .property-card .property-city { font-size: 9px; color: rgb(107, 109, 113); }
#     #results-container .property-card .property-card-attribution { padding-top: 5px; color: rgb(107, 109, 113); font-size: 8px; font-family: Oakes, Helvetica, Arial, sans-serif; line-height: 10px; padding-bottom: 10px; }
#     #results-container .property-card .property-actions { position: absolute; right: 2px; top: 10px; width: 38px; text-align: center; }
#     #results-container .property-card .property-actions .action-contact { font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; font-size: 10px; margin-bottom: 11px; display: block; background-image: url("/images/c21/propsearch/contact-2.svg"), linear-gradient(transparent, transparent); height: 36px; width: 36px; border: none; outline: 0px; cursor: pointer; background-size: 34px; background-position: center center; background-repeat: no-repeat no-repeat; }
#     #results-container .property-card .property-actions .action-favorite { font-family: BarlowSemiCondensed, Helvetica, Arial, sans-serif; font-size: 10px; display: block; background-image: url("/images/c21/propsearch/icon_save.svg"), linear-gradient(transparent, transparent); height: 30px; width: 36px; border: none; outline: 0px; cursor: pointer; background-size: 22px; background-position: center top; background-repeat: no-repeat no-repeat; }
#     .footerSeoContainer .footerSeo .rightSection .description .showMore-toggle, .footerSeoContainer .footerSeo .topSectionCity .description .showMore-toggle, .footerSeoContainer .footerSeo .topSectionNearbyCity .description .showMore-toggle, .footerSeoContainer .footerSeo .topSectionNearbyCounty .description .showMore-toggle, .footerSeoContainer .footerSeo .topSectionZip .description .showMore-toggle { display: none; }
#     .footerSeoContainer .footerSeo #showMoreSeoCities { display: none; }
#     .footerSeoContainer .footerSeo .rightSection .description a, .footerSeoContainer .footerSeo .rightSection .description label, .footerSeoContainer .footerSeo .topSectionCity .description a, .footerSeoContainer .footerSeo .topSectionCity .description label, .footerSeoContainer .footerSeo .topSectionNearbyCity .description a, .footerSeoContainer .footerSeo .topSectionNearbyCity .description label, .footerSeoContainer .footerSeo .topSectionNearbyCounty .description a, .footerSeoContainer .footerSeo .topSectionNearbyCounty .description label, .footerSeoContainer .footerSeo .topSectionZip .description a, .footerSeoContainer .footerSeo .topSectionZip .description label { color: rgb(37, 37, 38); }
#     .footerSeoContainer .footerSeo .rightSection .description > div:nth-child(n+7) a, .footerSeoContainer .footerSeo .topSectionCity .description > div:nth-child(n+7) a, .footerSeoContainer .footerSeo .topSectionNearbyCity .description > div:nth-child(n+7) a, .footerSeoContainer .footerSeo .topSectionNearbyCounty .description > div:nth-child(n+7) a, .footerSeoContainer .footerSeo .topSectionZip .description > div:nth-child(n+7) a { display: none; }
#     #site-footer .deco-logo { width: 130px; position: absolute; left: 50%; margin-left: -67px; top: -65px; }
#     #site-footer .footer-sections nav .showMore-toggle { display: none; position: absolute; left: -100%; top: -100%; }
#     .visible-sm-inline-block { display: none; }
#     #site-footer .language-chooser span { padding-right: 4px; }
#     #site-footer .footer-disclaimer .footer-row #cms-page-disclaimer { display: none; color: rgb(167, 167, 167); }
#     .hidden-sm-down { display: none; }
#     #site-footer .footer-disclaimer .footer-row .logo-seal { background-image: url("/images/portal/logo-seal-2.svg"), linear-gradient(transparent, transparent); background-size: contain; height: 64px; width: auto; background-position: left center; background-repeat: no-repeat no-repeat; }
#     #PageBody.Standard2LaneRight #BodyLeftLane .LaneTitle, #PageBody.Standard2LaneRight #BodyRightLane #contactCard .LaneTitle, #PageBody.Standard3Lane #BodyCenterLane .LaneTitle.TitleColspan, #PageBody.Standard3Lane #BodyLeftLane .LaneTitle, #PageBody.Standard3Lane #BodyRightLane .LaneTitle, #language-options-modal.language-options, #site-footer .footer-bottom, #site-footer .footer-sections nav div { font-family: Typold, Helvetica, Arial, sans-serif; }
#     #language-options-modal.language-options { overflow: auto; font-size: 11px; line-height: 25px; color: rgb(56, 56, 58); width: inherit; background-color: rgb(37, 37, 38); background-image: url("/images/portal/LanguageOverlay-375.png"); background-size: cover; padding: 20px; z-index: 10000; margin: 0px; position: fixed; top: 0px; right: 0px; left: 0px; height: 100vh; letter-spacing: 0.05em; display: none; animation-duration: 0.3s; animation-fill-mode: both; }
# ...
# <div><a aria-label="hidden" href="/real-estate/ithaca-ny/LCNYITHACA/?pt=2" onclick="Track.doEvent('ResultsFooter', 'Property Type', 'Townhouses');">Ithaca Townhouses for Sale</a></div>
# <div><a aria-label="hidden" href="/real-estate/ithaca-ny/LCNYITHACA/?pt=4" onclick="Track.doEvent('ResultsFooter', 'Property Type', 'Land');">Ithaca Land for Sale</a></div>
# <div><a aria-label="hidden" href="/real-estate/ithaca-ny/LCNYITHACA/?pt=7" onclick="Track.doEvent('ResultsFooter', 'Property Type', 'Apartments');">Ithaca Apartments for Sale</a></div>
# <div><a aria-label="hidden" href="/real-estate/ithaca-ny/LCNYITHACA/?pt=8" onclick="Track.doEvent('ResultsFooter', 'Property Type', 'Mobile &amp; Manufactured homes');">Ithaca Mobile &amp; Manufactured homes for Sale</a></div>
# <label for="showMoreSeoPropTypes"><span class="sr-only">Click to Show More Seo Proptypes</span></label>
# </div>
# </div>
# <div class="rightSection description">
#
#
#
#
#
#
#
#
#
#
#
#                            There are 139 real estate listings found in
#                            <a aria-label="hidden" href="/real-estate/ithaca-ny/LCNYITHACA/" onclick="Track.doEvent('ResultsFooter', 'Paragraph', 'Search');">Ithaca, NY</a>.
#
#
#
#
#
#
#                   View our
#                   <a aria-label="hidden" href="/real-estate-information/ithaca-ny/LCNYITHACA" onclick="Track.doEvent('ResultsFooter', 'Paragraph', 'Local Area');">Ithaca real estate area information</a> to learn about the weather, local school districts, demographic data, and general information about Ithaca, NY.
#                   Get in touch with an
#                   <a aria-label="hidden" href="/real-estate-agents/ithaca-ny/LCNYITHACA/" onclick="Track.doEvent('ResultsFooter', 'Paragraph', 'Agent Search');">Ithaca real estate agent</a>
#                   who can help you find the home of your dreams in Ithaca.
#                   Use our
#                   <a aria-label="hidden" href="/calculators/mortgage" onclick="Track.doEvent('ResultsFooter', 'Paragraph', 'Mortgage Calculator');">mortgage calculator</a>
#                   to see how much it would be to finance a home in Ithaca.
#                   Not ready to buy yet? Find and compare
#                   <a aria-label="hidden" href="/real-estate/ithaca-ny/LCNYITHACA/?ty=3" onclick="Track.doEvent('ResultsFooter', 'Paragraph', 'Rental');">apartments for rent in Ithaca</a>.
#
#
#          </div>
# </div>
# </div>
# <footer data-usagetrack-group="ResultsFooter" id="site-footer"> <div class="container"> <div class="row"> <div class="deco-logo"> <svg viewbox="0 0 130 130.18" xmlns="http://www.w3.org/2000/svg"><title>square-century21</title><g data-name="Layer 2" id="Layer_2"><g data-name="Layer 1" id="Layer_1-2"><path d="M15.48,26a12.93,12.93,0,0,0,8.34-3L21,18.82A8,8,0,1,1,21,7.14L23.82,3A13,13,0,1,0,15.48,26ZM125,0V17.44L113,0h-5V26h5V8.51L125,26h5V0ZM15.64,78.06v-21H23.3v-5H3v5h7.66v21ZM74.8,21H62.45V15.46h9.92v-5H62.45V5H74.8V0H57.5V26H74.8ZM71.89,67.37a5.74,5.74,0,1,1-11.48.15V52.1h-5V67.37a10.7,10.7,0,1,0,21.4,0V52.1h-5Zm.76,49.82.13-.19a8.2,8.2,0,1,0-15-4.58v.31h5c0-.1,0-.2,0-.31A3.24,3.24,0,0,1,66,109.18a3.13,3.13,0,0,1,3.25,3v.22a6.36,6.36,0,0,1-1,2.52L57.64,130.17h17v-4.95H67.09ZM129,60.82a8.72,8.72,0,0,0-8.71-8.71h-11.2v26h5V69.54h3.16l5.9,8.53H129l-6.16-8.91A8.73,8.73,0,0,0,129,60.82Zm-8.71,3.76H114V57.07h6.24a3.76,3.76,0,1,1,0,7.51Zm-5.73,44.6h2.7v21h5v-26h-7.65ZM13.16,114.72l-7.27-10.5H0l10.68,15.43v10.52h5V119.65l10.68-15.43H20.43Z" data-name="Path 1" id="Path_1"></path></g></g></svg> </div> <div class="col-sm-4 col-md-3"> <div class="footer-sidebar"> <span class="footer-phone"> <a data-ctc-track='["call-center-footer-CTC","call-hq"]' data-usagetrack-click="Phone/Contact" href="tel:8667326139">866-732-6139</a> </span> <div class="social-icons" data-usagetrack-group="Social"> <div class="social-icon-facebook social-icon"><a class="IconSocialMedia" data-usagetrack-click="Facebook" href="http://www.facebook.com/pages/CENTURY-21-Real-Estate-LLC/44054450913" rel="nofollow" target="_BLANK" title="You have selected a link to a website that is not owned or maintained by Century21.com. Different terms of use and privacy policies will apply.">Facebook</a> </div> <div class="social-icon-instagram social-icon"><a class="IconSocialMedia" data-usagetrack-click="Instagram" href="http://instagram.com/century21" rel="nofollow" target="_BLANK" title="You have selected a link to a website that is not owned or maintained by Century21.com. Different terms of use and privacy policies will apply.">Instagram</a> </div> <div class="social-icon-twitter social-icon"><a class="IconSocialMedia" data-usagetrack-click="Twitter" href="http://twitter.com/Century21" rel="nofollow" target="_BLANK" title="You have selected a link to a website that is not owned or maintained by Century21.com. Different terms of use and privacy policies will apply.">Twitter</a></div> <div class="social-icon-youtube social-icon"><a class="IconSocialMedia" data-usagetrack-click="YouTube" href="http://www.youtube.com/century21" rel="nofollow" target="_BLANK" title="You have selected a link to a website that is not owned or maintained by Century21.com. Different terms of use and privacy policies will apply.">YouTube</a></div> </div> <div class="footer-links" data-usagetrack-group="Footer Top"> <a data-usagetrack-click="Contact C21" href="/about-us/contact">Contact Us</a> <a data-usagetrack-click="FAQs" href="/about-us/about/faqs/buying-and-selling">FAQs</a> <a data-usagetrack-click="Sitemap" href="/sitemap">Sitemap</a> <a data-usagetrack-click="Terms and Conditions" href="/about-us/legal/terms">Terms &amp; Conditions</a> <a href="/about-us/accessibility-statement">Accessibility Statement</a> <a href="https://www.century21.com/sites/default/files/2022-07/ny-reasonable-accommodations-notice.pdf">NY Reasonable Accommodations Notice</a> </div> <div class="footer-links" data-usagetrack-group="Cookie Consent"> <div id="footerCookie" style="display: none;"></div> <div id="teconsent" style="display: none;"></div> <script async="async" crossorigin="" src="//consent.trustarc.com/notice?domain=century21.com&amp;c=teconsent&amp;js=nj¬iceType=bb&amp;text=true&gt;m=1"></script> </div> <div class="footer-links ccpa"> <a href="/about-us/legal/privacy">Privacy Policy</a> </div> </div> </div> <div class="col-sm-8 col-md-9 d-md-flex"> <div class="footer-sections shared interior"> <nav class="footer-sec ...
# </div>
# <div data-usagetrack-group="Map Tools" id="map-parent-container">
# <div id="map-error"></div>
# <div id="map-info"></div>
# <button data-usagetrack-click="Zoom In" id="control-zoom-plus"><span class="sr-only">Zoom In Control</span></button>
# <button data-usagetrack-click="Zoom Out" id="control-zoom-minus"><span class="sr-only">Zoom Out Control</span></button>
# <button id="control-map-type"><span class="sr-only">Map type Control</span></button>
# <div id="control-map-type-options"></div>
# <button id="control-draw"><span class="sr-only">Map Draw Tool</span></button>
# <button id="control-search-map">Search Entire Map</button>
# <div class="cloak-children" id="map-container"></div>
# <div id="lasso-tool"></div>
# </div>
# <div data-usagetrack-group="Property Results" id="pdp-parent-container">
# <div id="pdp-container">
# </div>
# <button data-usagetrack-click="Previous Listing" id="pdp-prev-button">Prev Listing</button>
# <button data-usagetrack-click="Next Listing" id="pdp-next-button">Next Listing</button>
# </div>
# </div>
# <div id="mobile-button-container"><button id="mobile-filter-button">Filter / Sort</button><button id="mobile-map-button">Map View</button><button id="mobile-list-button">List View</button><button id="mobile-save-search-button">Save Search</button></div>
# <div id="mobile-filter-panel"></div>
# </div>
# <script>require(['propsearch', 'newPortal','usageTrack','listTrac']);</script>
# <link as="style" href="/js/c21/third-party/photoswipe/photoswipe.css" onload="this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="/js/c21/third-party/photoswipe/default-skin/default-skin.css" onload="this.rel='stylesheet'" rel="preload"/>
# <noscript>
# <link href="/js/c21/third-party/photoswipe/photoswipe.css" rel="stylesheet"/>
# <link href="/js/c21/third-party/photoswipe/default-skin/default-skin.css" rel="stylesheet"/>
# </noscript>
# <div aria-hidden="true" class="pswp" role="dialog" tabindex="-1">
# <div class="pswp__bg"></div>
# <div class="pswp__scroll-wrap">
# <div class="pswp__container">
# <div class="pswp__item"></div>
# <div class="pswp__item"></div>
# <div class="pswp__item"></div>
# </div>
# <div class="pswp__ui pswp__ui--hidden">
# <div class="pswp__top-bar">
# <div class="pswp__counter"></div>
# <button class="pswp__button pswp__button--close" title="Close (Esc)"></button>
# <button class="pswp__button pswp__button--fs" title="Toggle fullscreen"></button>
# <button class="pswp__button pswp__button--zoom" title="Zoom in/out"></button>
# <div class="pswp__preloader">
# <div class="pswp__preloader__icn">
# <div class="pswp__preloader__cut">
# <div class="pswp__preloader__donut"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="pswp__share-modal pswp__share-modal--hidden pswp__single-tap">
# <div class="pswp__share-tooltip"></div>
# </div>
# <button class="pswp__button pswp__button--arrow--left" title="Previous (arrow left)">
# </button>
# <button class="pswp__button pswp__button--arrow--right" title="Next (arrow right)">
# </button>
# <div class="pswp__caption">
# <div class="pswp__caption__center"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#    require(['track'], function(Track) {
#       Track.includeFunctionalTag(function() {
#          var _comscore = _comscore || [];
#          _comscore.push({c1: "2", c2: "7705242"});
#          var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#          s.async = true;
#          s.defer = true;
#          s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#          el.parentNode.insertBefore(s, el);
#
#          var img = document.createElement('img');
#          img.src = "https://b.scorecardresearch.com/p?c1=2&c2=7705242&cv=2.0&cj=1";
#          img.width = "1";
#          img.height = "1";
#          img.style = "display:none";
#          document.getElementsByTagName('body')[0].appendChild(img);
#       });
#    });
# </script>
# <!--
# <noscript>
# <img src="//b.scorecardresearch.com/p?c1=2&c2=7705242&cv=2.0&cj=1">
# </noscript>
# -->
# <!-- Facebook Pixel Code -->
# <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#          n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#       n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#          document,'script','https://connect.facebook.net/en_US/fbevents.js');
#       require(['track'], function(Track) {
#          Track.includeAdTag(function () {
#             fbq('init', '1660237170895659'); // Insert your pixel ID here.
#             fbq('track', 'PageView');
#          });
#       });
# </script>
# <!--<noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1660237170895659&ev=PageView&noscript=1"/></noscript>-->
# <!-- End Facebook Pixel Code -->
# <script>
#    require(['track'], function(Track) {
#       Track.includeFunctionalTag(function() {
#          var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#          s.async = true;
#          s.src = (document.location.protocol == "https:" ? "https://" : "http://") + "cdn.bttrack.com/js/14158/analytics/1.0/analytics.min.js";
#          el.parentNode.insertBefore(s, el);
#       });
#    });
# </script>
# <script>
#    require(['track'], function(Track) {
#       Track.includeFunctionalTag(function() {
#          var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#          s.async = true;
#          s.defer = true;
#          s.src = (document.location.protocol == "https:" ? "https://" : "http://") + "code.listtrac.com/monitor.ashx?acct=x_100710&nonjq=1";
#          el.parentNode.insertBefore(s, el);
#       });
#    });
#
#    window.__deferredListTracCallbacks = [];
#
#    window.__waitForListTrac = function () {
#       if (typeof _LT !== 'undefined') {
#          window.__deferredListTracCallbacks.forEach(function (callback) {
#             return callback();
#          });
#       } else {
#          setTimeout(__waitForListTrac, 200);
#       }
#    };
#
#    window.__onListTracLoaded = function (callback) {
#       if (typeof _LT !== 'undefined') {
#          callback();
#       } else {
#          if (!window.__deferredListTracCallbacks.length) {
#             setTimeout(__waitForListTrac, 1);
#          }
#
#          window.__deferredListTracCallbacks.push(callback);
#       }
#    };
# </script>
# <script class="botcopy-embedder-d7lcfheammjct" data-botid="5ffcf1fb24e59300089789ee" data-requirejs="true" id="botcopy-embedder-d7lcfheammjct" type="text/javascript">
# </script>
# <script>
#       // This code has been added since XTDirect botcopy chat is injecting third-party GTM.
#       require(['track'], function(Track) {
#          Track.includeFunctionalTag(function() {
#             $('.header-chat').show();
#             var s = document.createElement('script');
#             s.type = 'text/javascript'; s.async = true;
#             s.src = 'https://widget.botcopy.com/js/injection.js';
#             document.getElementById('botcopy-embedder-d7lcfheammjct').appendChild(s);
#          }, true);
#       });
#    </script>
# <script>
#    require(['portalSearch', 'track', 'jquery', 'portalAjax', 'contactForms', 'formValidator'], function(portalSearch, track, $, portalAjax) {
#       portalSearch.createSearchField();
#       $.getScript(portalAjax.getPersonalUrl() + '/dynamicDependencies/dynamic.js');
#       $.each(window.m_aDeferredMethods, function (i, fn) {
#          fn();
#       });
#       window.m_aDeferredMethods = false;
#    });
# </script>
# <script>
#    loadCSS('/css/searchresults.css?__VERSION=020820241425');
#    loadCSS('/css/modals/modalWindows.css?__VERSION=020820241425');
#    loadCSS('/css/modals/createAccount.css?__VERSION=020820241425');
#    loadCSS('/css/modals/forgotPassword.css?__VERSION=020820241425');
#    loadCSS('/css/modals/contactProperty.css?__VERSION=020820241425');
#    loadCSS('/css/modals/contact.css?__VERSION=020820241425');
#    loadCSS('/css/modals/login.css?__VERSION=020820241425');
#    loadCSS('/css/modals/saveSearch.css?__VERSION=020820241425');
#    loadCSS('/css/icons.css?__VERSION=020820241425');
#    loadCSS('/css/locationsearch.css?__VERSION=020820241425');
# </script>
# <noscript>
# <link href="/css/searchresults.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/modalWindows.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/createAccount.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/forgotPassword.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/contactProperty.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/contact.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/login.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/modals/saveSearch.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/icons.css?__VERSION=020820241425" rel="stylesheet"/>
# <link href="/css/locationsearch.css?__VERSION=020820241425" rel="stylesheet"/>
# </noscript>
# <script>
#    defer(function () {
#       require(['jquery'], function($) {
#          $('style.critical-css').remove();
#          $('.cloak').removeClass('cloak');
#          $('.cloak-children').removeClass('cloak-children');
#       });
#    });
# </script>
# </body>
# </html>

# %% [markdown]
# Once we have parsed the HTML data, we can use Beautiful Soup to find the data we need. We can do this by using various methods provided by Beautiful Soup, such as `find()`, `find_all()`, and `select()`, to locate the HTML elements that contain the data we need.
#
# For example, if we want to find all the links on the website, we can use the `find_all()` method to find all the `<a>` tags on the page and then extract the href attributes:

# %%
prices = []
for link in soup.find_all('a', class_= 'listing-price'):
    prices.append(link.text.replace(' ',"").replace('\n',""))

beds = []
for link in soup.find_all('div', class_= 'property-beds'):
    beds.append(link.text.replace(' ',"").replace('\n',"").replace('beds',''))

sqfts = []
for link in soup.find_all('div', class_= 'property-sqft'):
    sqfts.append(link.text.replace(' ',"").replace('\n',"").replace('sq.ft','').replace(',',''))

addresses = []
for link in soup.find_all('div', class_= 'property-address'):
    addresses.append(link.text.replace('               ',"").replace('            ',"").replace('\n',''))

# %%
prices
# Out:
# ['$525,000',
#  '$821,000',
#  '$399,900',
#  '$1,089,000',
#  '$365,000',
#  '$199,000',
#  '$429,000',
#  '$250,000',
#  '$459,000',
#  '$450,000',
#  '$238,000',
#  '$460,900',
#  '$280,000',
#  '$264,000',
#  '$895,000',
#  '$375,000',
#  '$849,000',
#  '$505,000',
#  '$375,000',
#  '$374,000']

# %%
beds
# Out:
# ['4',
#  '6',
#  '3',
#  '5',
#  '3',
#  '2',
#  '3',
#  '3',
#  '3',
#  '3',
#  '2',
#  '3',
#  '3',
#  '3',
#  '5',
#  '2',
#  '3',
#  '2',
#  '3']

# %%
sqfts
# Out:
# ['2082',
#  '5070',
#  '2228',
#  '3589',
#  '1412',
#  '858',
#  '2204',
#  '1518',
#  '2631',
#  '2016',
#  '900',
#  '2918',
#  '1625',
#  '1713',
#  '3991',
#  '1720',
#  '1992',
#  '1544',
#  '1981']

# %%
addresses
# Out:
# ['229 Valley Road',
#  '116 LARISA Lane',
#  '145 Muzzy Road',
#  '72 Tigerlily Lane',
#  '210 East Falls Street',
#  '1033 CODDINGTON Road',
#  '112 Penny Lane',
#  '1 Lansing Heights Road',
#  '309 Saranac Way',
#  '1885 Ellis Hollow Road',
#  '2250 North Triphammer Rd. #T1C Road',
#  '213 Tareyton Drive',
#  '1700 Slaterville Road',
#  '321 Hector Street',
#  '110 HIGHLAND Avenue',
#  '231 VALLEY Road',
#  '680 Warren Road',
#  '131 Simsbury Drive',
#  '311 Linn Street',
#  '118 WOOLF Lane']
